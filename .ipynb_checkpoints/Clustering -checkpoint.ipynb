# %%
#Importing Libraries
import numpy as np
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile

# %%
#Importing the dataset and specifying no header
data = "news_training.xlsx"
news_headlines = pd.read_excel(data, header= None)

# %%
#Adding column names
news_headlines.columns = ['Date', 'Headline']
news_headlines.head()
# Out:
#                             Date  \
# 0  2018-04-02T00:47:00.000+03:00
# 1  2018-01-03T01:34:00.000+02:00
# 2  2018-01-03T00:59:00.000+02:00
# 3  2018-05-02T14:30:00.000+03:00
# 4  2018-05-02T18:44:00.000+03:00
#
#                                             Headline
# 0  b"Mexican presidential front-runner hits back ...
# 1  b"Cramer reflects on how Trump's actions are f...
# 2  b'The Wall Street Journal: Peter Thiels VC fir...
# 3  b'WSJ Wealth Adviser Briefing: Catchy Tickers,...
# 4  b'Apple proved that it is no longer just an iP...

# %%
#Converting datetime to month/day/year format
news_headlines['Date'] = pd.to_datetime(news_headlines['Date'], infer_datetime_format=True)
news_headlines['Date'] = news_headlines['Date'].dt.strftime('%m/%d/%Y')

# %%
news_headlines.head()
# Out:
#          Date                                           Headline
# 0  04/01/2018  b"Mexican presidential front-runner hits back ...
# 1  01/02/2018  b"Cramer reflects on how Trump's actions are f...
# 2  01/02/2018  b'The Wall Street Journal: Peter Thiels VC fir...
# 3  05/02/2018  b'WSJ Wealth Adviser Briefing: Catchy Tickers,...
# 4  05/02/2018  b'Apple proved that it is no longer just an iP...

# %%
#Import regex library 
import re

#Cleaning Headlines
news_headlines["Headline"] = news_headlines['Headline'].map(lambda x: re.sub(r'^b', '', x))
news_headlines["Headline"] = news_headlines['Headline'].map(lambda x: re.sub(r'\b["",\']', '', x))
news_headlines.head()
# Out:
#          Date                                           Headline
# 0  04/01/2018  Mexican presidential front-runner hits back at...
# 1  01/02/2018  Cramer reflects on how Trumps actions are fuel...
# 2  01/02/2018  The Wall Street Journal: Peter Thiels VC firm ...
# 3  05/02/2018  WSJ Wealth Adviser Briefing: Catchy Tickers Gu...
# 4  05/02/2018  Apple proved that it is no longer just an iPho...

# %%
#Listing dataframe
prev = news_headlines.values.tolist()
prev
# Out:
# [['04/01/2018',
#   "Mexican presidential front-runner hits back at Trumps NAFTA threat blasts 'pinata treatment"],
#  ['01/02/2018',
#   "Cramer reflects on how Trumps actions are fueling the 'beast market rally"],
#  ['01/02/2018',
#   'The Wall Street Journal: Peter Thiels VC firm has made a monster bet on bitcoin'],
#  ['05/02/2018',
#   'WSJ Wealth Adviser Briefing: Catchy Tickers Gun Purchase Monitoring Diet Vodka'],
#  ['05/02/2018', 'Apple proved that it is no longer just an iPhone company'],
#  ['05/02/2018', 'App redesign haunts Snap as investors flee stock'],
#  ['05/02/2018',
#   'The dollar is surging into overbought territory warns chart watcher. Heres what it means'],
#  ['05/02/2018', 'UPS weighs strategy to deliver bulky goods to boost growth'],
#  ['05/02/2018',
#   'Yum Brands to report earnings before the opening bell. Heres what to expect'],
#  ['05/02/2018',
#   'Tesla sued by truck start-up which alleges that its design patent was violated'],
#  ['05/02/2018',
#   'Everything went backwards at Snap and they are in the penalty box: Fmr. Yahoo COO'],
#  ['01/01/2018',
#   'UKs Compass says new CEO to start Jan 1 after death of Cousins - Reuters'],
#  ['04/03/2018', "CBS submits below market value bid for VIACOM...'"],
#  ['04/03/2018',
#   "NBA star Andre Iguodala says his teams 'locker room talk is all business"],
#  ['04/03/2018', 'Snapchat Introduces New Group Video Chat Feature'],
#  ['03/02/2018', 'Trump made tariff decision in a fit of anger: NBC News'],
#  ['03/02/2018',
#   'Mueller probing whether Kushners foreign business ties affected White House policies: NBC News'],
#  ['02/28/2018',
#   'UPDATE 1-U.S. ag secretary seeks to calm farmers after Trump biofuel talks'],
#  ['03/02/2018',
#   'Amazon scrambles to fix cloud networking issue affecting companies like Atlassian Twilio'],
#  ['03/01/2018', 'US consumer inflation picks up in January as spending slows'],
#  ['03/01/2018',
#   'This $20 million Florida mansion has a closet just for $100000 worth of Air Jordans'],
#  ['03/01/2018',
#   'Equifax finds an additional 2.4 million Americans impacted by 2017 breach'],
#  ['04/02/2018', 'Commodities tomorrow: Crude tumbles with stocks'],
#  ['04/03/2018',
#   'Microsoft calls for dismissal of U.S. Supreme Court privacy fight'],
#  ['03/02/2018', 'Cramer: If Gary Cohn resigns watch out stock market'],
#  ['03/02/2018',
#   'IMF warns that steel aluminum tariffs will likely hurt economies'],
#  ['03/02/2018',
#   'You could tank your chance of getting an offer if you bring this up too early in a job interview'],
#  ['05/01/2018',
#   'WSJ City PM: Barclays Begins Search for New Chairman EU Concerns Linger Despite Extra Time on Tariffs Ether Faces Scrutiny'],
#  ['05/02/2018',
#   'Dr. Oz: We need to make life-saving health tech for everyone not just for rich people'],
#  ['05/02/2018',
#   'Market correction of 30-40% could be coming soon investment guru Mark Mobius warns'],
#  ['05/02/2018',
#   'Earnings are blockbuster but markets arent listening. Heres why'],
#  ['05/02/2018', 'Apple Has Already Built Its Next Big Business'],
#  ['05/02/2018', "Down In Front! (Thursday May 3)'"],
#  ['05/03/2018',
#   'Twitter says it found a password bug and that you should change yours'],
#  ['03/01/2018',
#   'Heres what you need to earn to buy a home in these big cities'],
#  ['02/01/2018',
#   "Vloggers created a $205 'Big Mac with Wagyu beef and Veuve Clicquotheres everything in it"],
#  ['03/05/2018',
#   'Dubai International Financial Centre sees higher growth in new companies - Reuters'],
#  ['05/03/2018',
#   'Real Time Economics: The Fed | Chinese Trade Politics | Jobs Guarantee - Real Time Economics - WSJ'],
#  ['03/05/2018',
#   'Bill Cosby will fight bid to call more accusers at sexual abuse retrial'],
#  ['03/05/2018',
#   'Trump-Netanyahu meeting is chance to project common front vs. Iran'],
#  ['03/05/2018',
#   'Egypt TV host released on bail after being held for defaming police: sources'],
#  ['03/06/2018',
#   "This international stock is the 'least shortable' when it comes to China stocks"],
#  ['03/06/2018',
#   "Harley-Davidson says retaliatory tariffs will have a 'significant impact on sales"],
#  ['03/06/2018',
#   'Billy McFarland organizer of disastrous Fyre Festival pleads guilty to misleading investors'],
#  ['03/06/2018',
#   'Coinbases bitcoin cash trading rollout cost investors $5 million lawsuit says'],
#  ['03/05/2018',
#   'Cramer: When it comes to China tariffs this international stock is the \'least shortable"'],
#  ['03/06/2018',
#   'Heres another reason to think twice before using your debit card'],
#  ['02/01/2018',
#   'Viacom board said to be in talks to set up committee to explore CBS deal'],
#  ['02/01/2018',
#   'Elon Musks Boring Company sells all of its flamethrowers in less than a week'],
#  ['01/01/2018', 'Bitcoin Is Already Having a Bad Year'],
#  ['01/02/2018', 'Scenes from deadly protests in Iran'],
#  ['01/01/2018',
#   'American Girl Debuts New Doll an Aspiring Astronaut Named Luciana'],
#  ['05/03/2018', '4 reasons crypto still isnt mainstream'],
#  ['05/03/2018', 'The surprising story behind Trader Joes 19 cent bananas'],
#  ['05/03/2018',
#   'Born in a dishwasher drawer an Italian spin on currency mining'],
#  ['05/02/2018', 'Euro zone economy slows as expected in first quarter'],
#  ['05/03/2018', 'Trumps New Lawyer Has Unique Rsum - Washington Wire - WSJ'],
#  ['02/02/2018', 'Where the jobs are: Houstons police shortage'],
#  ['02/02/2018', 'Nvidias massive run reminds me of the tech bubble'],
#  ['04/02/2018', 'Energy sector in correction territory'],
#  ['03/02/2018',
#   'No-frills micro hospitals with as few as 8 rooms emerge as a new way to cut health-care costs'],
#  ['03/02/2018',
#   'Why Verizons CEO is banking on diversityand asking men to help'],
#  ['05/02/2018',
#   'Commodities tomorrow: Crude up in spite of bearish inventory report'],
#  ['05/03/2018',
#   'Retail leads planned job cuts in 2018 while technology bounces back'],
#  ['03/01/2018',
#   '15000 internet-connected devices could be hacked to mine $1000 of cryptocurrency in 4 days'],
#  ['04/02/2018',
#   'McDonalds Workers Say the Company Is Breaking Its Minimum Wage Pledge'],
#  ['04/02/2018',
#   'China Calls for Trade Talks as Retaliatory Tariffs on U.S. Goods Take Effect'],
#  ['01/03/2018',
#   'U.S. factory activity accelerates; construction spending at record high'],
#  ['01/02/2018', 'Your first bitcoin trade for the new year'],
#  ['01/02/2018', 'EMERGING MARKETS-LatAm markets kick off 2018 with a rally'],
#  ['02/02/2018',
#   'P&G and these other Dow stocks go down the least when market is in the grips of a sell-off'],
#  ['02/02/2018',
#   'US consumer sentiment falls less than expected remaining near all-time highs'],
#  ['05/01/2018',
#   'Deutsche Telekom Expects Debt Repayment If T-Mobile Buys Sprint - CFO Journal. - WSJ'],
#  ['05/01/2018',
#   'Brexit & Beyond: U.S. Allies Worry About Trumps Next Trade Move'],
#  ['05/01/2018',
#   'US extends tariff exemptions for European Union and other allies'],
#  ['05/03/2018',
#   'WSJ City: Tesla Burns Through Cash U.S. Weighs Curbs on China Telecom Firms'],
#  ['05/03/2018',
#   "A big trade deal 'unlikely to happen with Trumps team in China: Former government official"],
#  ['05/02/2018', 'Podcast: Blockchain as Lie Detector'],
#  ['05/02/2018',
#   'BRIEF-Thomson Reuters Provides Information Related To Future Financial Reporting Outlook - Reuters'],
#  ['05/01/2018',
#   'Why trade wars can be fantastically disruptive the IMFs historian warns'],
#  ['02/01/2018', 'Apple earnings are coming after the bell'],
#  ['02/01/2018', 'Your first trade for Thursday February 1'],
#  ['04/02/2018',
#   "'This is more of a phony war than a real trade war: Strategist"],
#  ['01/03/2018', 'Southwest Airlines to Boeing: Well take the large'],
#  ['01/03/2018',
#   'UPDATE 1-Petrobras to pay $2.95 bln to settle U.S. class action over corruption'],
#  ['01/03/2018',
#   'Tesla delivers 1550 Model 3 sedans and 29870 total vehicles in fourth quarter'],
#  ['01/03/2018',
#   'UPDATE 2-Brazils Petrobras settles U.S. corruption class action for $2.95 bln'],
#  ['01/03/2018', 'Ubers Financials: An Inside Look - Wall Street Journal'],
#  ['01/02/2018',
#   'US appeals court revives proposed debt collection class action - Reuters'],
#  ['01/31/2018',
#   'Humor Rivalry and Billions of Dollars: A Brief History of Super Bowl Ads'],
#  ['02/02/2018', 'Heres where the jobs are  in one chart'],
#  ['02/01/2018',
#   'UPDATE 1-Swiss bank PKB broke money-laundering rules in Brazilian cases - FINMA'],
#  ['02/02/2018',
#   'Britains May gets $13.26 billion in China deals Xi promises to build on \'golden era"'],
#  ['02/02/2018',
#   'Earnings are up and revenue growth is back but rate hikes could derail momentum'],
#  ['02/01/2018',
#   'Cramer tackles Facebook Apple Amazon and Alphabet earnings as tech giants report'],
#  ['04/02/2018',
#   'Buy Intel because Apples reported move to abandon its chips is not a major threat Stifel says'],
#  ['04/02/2018',
#   "Limited fallout has been seen from Chinas 'old economy: Economist"],
#  ['02/28/2018', 'Senators will try to pull U.S. from Yemen war'],
#  ['03/01/2018',
#   'Elon Musks brother Kimbal: This was the \'best decision of my life"'],
#  ['04/01/2018', 'U.S. safety agency criticizes Tesla crash data release'],
#  ['02/04/2018',
#   'China accuses US of "Cold War mentality with new nuclear policy'],
#  ['04/30/2018', 'Cramer Remix: The world has turned on this sector'],
#  ['05/01/2018',
#   'Watch: Pelicans crash a California graduation and 1 lands on the red carpet'],
#  ['02/05/2018',
#   "US forces begin reducing numbers in Iraq after Iraq declares 'victory over Islamic State"],
#  ['02/05/2018', 'No signs of an imminent recession: Strategist'],
#  ['01/01/2018', 'Copper prices set to continue gains in 2018'],
#  ['01/02/2018',
#   'US looks good in 2018 but stocks abroad look even better says Invesco'],
#  ['04/02/2018',
#   'Japans Abe will visit US from April 17 to 20 for talks with Trump'],
#  ['05/02/2018',
#   'At least five dead in crash of Puerto Rican Air National Guard cargo plane'],
#  ['01/02/2018', 'Data SheetAn Apple Conspiracy Theory Blooms'],
#  ['01/02/2018', 'Chinas WeChat denies storing user chats'],
#  ['05/02/2018',
#   'The analysts were wrong: The iPhone X is still the most popular iPhone'],
#  ['03/01/2018',
#   'With surprise tariffs Trump rolls the dice with the US economy'],
#  ['03/01/2018', 'Gap shares soar on earnings beat'],
#  ['02/28/2018', 'Medtronic takes another step toward value-based care'],
#  ['01/02/2018', "Will central banks undershoot on inflation in 2018?'"],
#  ['01/02/2018',
#   'Cramers S&P 500 and Dow charts indicate a strong start to 2018'],
#  ['01/03/2018',
#   'Vice Suspends Two Brotopia Iceland Equal Pay: Broadsheet for January 3rd'],
#  ['05/02/2018',
#   'WSJ City PM: Why Central Banks Sway Over Markets Is Here to Stay the Still Lucrative iPhone What to Expect from the Fed'],
#  ['02/28/2018',
#   'Commodities tomorrow: Inventory build rise in production hit oil'],
#  ['02/02/2018',
#   'Here are the 10 most important stories for investors Friday morning'],
#  ['02/01/2018',
#   'This new group is angry about high drug prices  and plan to make 2018 candidates pay attention'],
#  ['02/01/2018',
#   'In the midst of the #MeToo movement office romance hits a 10-year low'],
#  ['02/01/2018',
#   'Surging rates wont hurt rally thanks to tax reforms extraordinary benefits says Ed Yardeni'],
#  ['02/01/2018',
#   'Release the GOP Russia memo. We deserve government transparency'],
#  ['03/02/2018', 'What Hollywood can teach Trump about trade'],
#  ['01/03/2018', '2018 ETF market predictions'],
#  ['01/03/2018',
#   'Palestinians condemn Trumps threat to halt aid payments saying \'We will not be blackmailed"'],
#  ['01/03/2018',
#   'The off-price sector long retails favorite could be losing steam in 2018'],
#  ['02/01/2018',
#   'UPenn to remove Steve Wynns name from outdoor plaza revoke his honorary degree'],
#  ['02/01/2018',
#   'GOP memo about the Russia probe is likely to be released soon. Heres what to watch for'],
#  ['02/01/2018', 'Watch: President Trump speaks at GOP lawmakers retreat'],
#  ['05/02/2018',
#   'Climate Change May Deeply Wound Long-Term U.S. Growth Richmond Fed Paper Finds'],
#  ['05/02/2018', 'User growth sinks and hits Snap shares'],
#  ['05/01/2018',
#   'Food photos and music: These top millennial stocks could see huge moves on earnings this week'],
#  ['05/01/2018',
#   'These charts show Apple is ripe for an earnings breakout technician says'],
#  ['05/01/2018',
#   'Saving in an IRA has its rewards  and risks  for these high-income earners'],
#  ['05/01/2018',
#   'Apple shares to rally more than 30% the next 12 months because of its high margins valuable brand: Analyst'],
#  ['01/02/2018',
#   'What are the nuances of Chinas planned tax on asset management products?"'],
#  ['05/02/2018', 'Macys acquires New York concept shop Story'],
#  ['05/02/2018',
#   'Australia: UPDATE 2-Australias CBA ordered to boost capital until governance failings fixed'],
#  ['05/02/2018',
#   "Cramer: Snaps earnings call was like a 'Saturday Night Live parody"],
#  ['05/01/2018', 'Verizons Oath signs distribution deal with Samsung'],
#  ['05/02/2018', 'Brazil drought hits second-corn dry spell persists'],
#  ['05/03/2018',
#   'Oil Prices Steady as Deadline on Iran Nuclear Deal NearsEnergy Journal'],
#  ['01/02/2018', "Orrin Hatch Retiring...'"],
#  ['03/01/2018', 'Visa just made a huge commitment on renewable electricity'],
#  ['02/28/2018',
#   'Cramer: Use declines to buy not sell stocks like Boeing and Apple'],
#  ['02/28/2018',
#   'Walmart says it will raise age restriction to 21 for gun purchases'],
#  ['05/02/2018', 'Eurozone Economy Stumbles in First Quarter'],
#  ['05/02/2018',
#   'Parsing the Fed: How the May Statement Changed From March - Real Time Economics - WSJ'],
#  ['01/02/2018',
#   'Asian factories end robust 2017 on mixed note; central banks seen hiking slowly'],
#  ['05/01/2018',
#   'Cramer: The selling has gone too far especially after Trumps tax cuts'],
#  ['05/02/2018',
#   'Oprah gave ex-NFL star Ricky Williams the best advice he ever got  and anyone can follow it'],
#  ['05/02/2018',
#   'Sellers are increasingly stripping out luxury homes instead of tricking them out'],
#  ['04/02/2018',
#   'Amazon vs. Trump China Tariffs Saks Hack: CEO Daily for April 2 2018'],
#  ['04/03/2018',
#   'Woman executive of South Koreas Hyundai Motor resigns amid #MeToo wave: Yonhap'],
#  ['04/02/2018', 'The Dow Drops: 7 trades'],
#  ['01/02/2018', 'The 10 biggest charitable gifts of 2017'],
#  ['05/02/2018',
#   'These retirees may see their Medicare costs rise by more than 200 percent'],
#  ['05/02/2018',
#   'U.N. experts say Congo obstructs probe of U.N. monitors killings: note'],
#  ['03/01/2018', 'Your first trade for Thursday March 1'],
#  ['02/28/2018', "The oil market has found a 'very sweet spot right now"],
#  ['02/28/2018', "Trump Asks Congress for 'Strong Gun Bill"],
#  ['03/01/2018',
#   'Watch Jaguar unveil its first all-electric vehicle designed to take on Tesla Model X'],
#  ['02/01/2018', 'Germany opens anti-trust probe into online advertising'],
#  ['01/03/2018',
#   'Here are the 10 most important stories for investors Wednesday morning'],
#  ['01/02/2018', 'U.S. threatens to withhold aid cash to Palestinians'],
#  ['04/02/2018', 'The 3 Best Bank Stocks for an Aging Bull Market'],
#  ['03/02/2018',
#   'China has fewer rich lawmakers but their fortunes have grown'],
#  ['03/02/2018', 'The timing of the proposed US steel tariffs is out of synch'],
#  ['04/03/2018',
#   'Mueller Was Authorized to Investigate Paul Manaforts Work for Ukraine'],
#  ['04/03/2018',
#   'Bitcoin just had its worst start to the year ever. Heres why this quarter could be better'],
#  ['03/01/2018', "General Motors February sales down 6.9% vs. 3.0% est.'"],
#  ['05/01/2018',
#   'Cramer reflects on Apple earnings after speaking with CEO Tim Cook'],
#  ['01/31/2018', 'UPDATE 2-Shell ahead in Mexico oil auction wins five blocks'],
#  ['02/02/2018',
#   '1 million US jobs will vanish by 2026. Heres how to prepare workers for an automated future'],
#  ['02/02/2018', 'Heres the stock markets big sell-off by the numbers'],
#  ['02/01/2018',
#   'Justice Department requests more information on CVS-Aetna merger'],
#  ['04/30/2018',
#   'EMERGING MARKETS-Latin American equities mixed amid light trading'],
#  ['02/02/2018',
#   'REFILE-UPDATE 2-Swiss bank PKB broke money-laundering rules in Brazilian cases - FINMA'],
#  ['02/02/2018',
#   'As retailers herald tax savings theyre still closing stores and laying off workers'],
#  ['04/02/2018', "Trump declares DACA 'dead' urges Congress to act on border"],
#  ['01/03/2018',
#   'Mobileye deal boosts Israeli high-tech exits to $23 billion in 2017'],
#  ['01/03/2018', 'Nigerias Buhari re-election movement gathers pace for 2019'],
#  ['01/02/2018',
#   'GRAINS-U.S. wheat rallies as temperatures fall; corn soy firm'],
#  ['01/02/2018', 'FDA issues recall on Johnson & Johnson heart device'],
#  ['02/01/2018',
#   'Strategist Jim Paulsen: The stock market could be heading for a 15% correction'],
#  ['02/01/2018',
#   'Do Standing Desks Really Help You Lose Weight? The Verdict Is In'],
#  ['02/01/2018',
#   'What to expect when Alphabet FANGs true blue chip reports earnings'],
#  ['03/02/2018', 'Beaten Dow stock Exxon could rally 30%, says energy analyst'],
#  ['04/03/2018',
#   'Migrant caravan heading to U.S. border puts Mexico in tough spot with Trump'],
#  ['04/02/2018',
#   'JPMorgans top blockchain executive Amber Baldet to leave for own startup'],
#  ['04/03/2018',
#   'Earnings reports cant get here soon enough for a market trying to find its footing'],
#  ['02/02/2018',
#   "Crude oil has 'nowhere to go from here but down' says market watcher"],
#  ['01/31/2018', 'Brazils pre-salt reserves provide half of oil production'],
#  ['02/02/2018',
#   'Former FBI director Comey defends the FBI slams \'weasels and liars"'],
#  ['02/02/2018',
#   'Janet Yellen exits the Fed today amid both heavy praise and bitter criticism'],
#  ['02/02/2018', 'Mortgage rates jump even higher after positive jobs report'],
#  ['02/02/2018',
#   'Deutsche Bank posts third consecutive annual loss in 2017 - Reuters'],
#  ['03/01/2018',
#   'Larry Kudlow: Trumps tariffs a \'bad omen and could cause \'major calamity"'],
#  ['03/01/2018', 'US weekly jobless claims drop to lowest level since 1969'],
#  ['05/02/2018',
#   'Stocks to Watch: Apple T-Mobile Mastercard Snap CVS Mondelez Xerox Gilead Clorox Allstate Coors - MoneyBeat - WSJ'],
#  ['05/02/2018', 'Unhappy Soccer Fans No Good for Gambling Group'],
#  ['05/02/2018', "BEIJING INSTALLS MISSILE SYSTEMS IN S. CHINA SEA...'"],
#  ['05/01/2018',
#   'Facebook privacy scandal wont slow Main Street retailers social ad spend'],
#  ['05/01/2018',
#   "Facebook smart speakers may come to international markets first will include 'M smart assistant"],
#  ['05/01/2018',
#   'Disney is launching a digital food channel called Disney Eats'],
#  ['04/30/2018',
#   'US wants 4-year phase-in for higher NAFTA auto content thresholds'],
#  ['01/03/2018',
#   'Amazon Echo vs. Google Home: How Competing Price Cuts Dominated the Holiday Season'],
#  ['05/01/2018', 'The states with the highest and lowest credit card balances'],
#  ['03/01/2018',
#   'The worlds largest ad agency just had $2.6 billion wiped off its market cap'],
#  ['03/01/2018', 'Women looking for Oscar love in best picture cliffhanger'],
#  ['03/01/2018',
#   "A '90s-style personal digital assistant thats a smartphone with a keyboard has launched in case you miss BlackBerry"],
#  ['03/02/2018', 'A photographers journey out of Venezuela'],
#  ['03/02/2018',
#   'The latest tariffs are \'indicative of the Trump administrations policy towards trade"'],
#  ['03/02/2018', 'Special report: A journey on a caravan of misery'],
#  ['03/02/2018', "Trump tariff concerns too extreme?'"],
#  ['04/03/2018', 'NY Fed names Williams to top post amid political backlash'],
#  ['04/02/2018', 'Migrant Caravan in Mexico Raises Trumps Ire'],
#  ['04/03/2018',
#   'Villanova takes NCAA mens basketball title 79-62 over Michigan'],
#  ['04/03/2018',
#   'Amazon shares turn negative after Trump bashes company for a fourth time in a week'],
#  ['04/01/2018', 'Palestinian Protests Pose Fresh Hurdles for Israel'],
#  ['04/02/2018', 'Two Can Play at Trade War'],
#  ['04/03/2018',
#   'Both Silicon Valley and Wall Street are taking notes on Spotifys unconventional debut'],
#  ['02/01/2018',
#   'CBS and Viacom boards form exploratory committees and hire bankers to mull a deal'],
#  ['02/02/2018',
#   'A leading indicator for stocks is waving a yellow flag for the market'],
#  ['05/02/2018', 'The best credit card for international travel'],
#  ['02/04/2018', 'How to Watch the 2018 Super Bowl Online for Free'],
#  ['04/01/2018', "Insults fly after Gaza deaths...'"],
#  ['01/02/2018',
#   'Cramers lightning round: Buy Becton Dickinsons stock hand over fist'],
#  ['01/02/2018', 'After-hours buzz: MGI TTPH & more'],
#  ['01/03/2018',
#   'German hate speech law tested as Twitter blocks satire account'],
#  ['01/03/2018',
#   'Spark prices the first US gene therapy drug at $850000  which is actually less than expected'],
#  ['05/02/2018',
#   'Irish High Court refuses Facebook bid to delay privacy case referral'],
#  ['05/02/2018',
#   "United Will Soon Allow Some Cats and Dogs Back Into Its Cargo Holds. Here Are the New Rules.'"],
#  ['05/02/2018',
#   "Bond market will suffer some 'indigestion as Fed prepares to charge market watcher says"],
#  ['05/02/2018',
#   'As the dollar soars emerging markets could be running into trouble trader warns'],
#  ['04/02/2018', 'You Can Get Free Little Caesars Pizza Today'],
#  ['04/02/2018', 'Intel shares tumble on report of Apple chip switch'],
#  ['03/01/2018', "Ford February US sales drops 6.9%'"],
#  ['04/02/2018',
#   'Elon Musk Is Trying to Laugh His Way Out of Teslas Worst Month in 7 Years'],
#  ['05/02/2018',
#   '4 life goals Americans are putting off because they cant pay their debt'],
#  ['05/02/2018',
#   'Clean energy sector swings Republican with U.S. campaign donations'],
#  ['01/02/2018',
#   'Times Up Hoda Kotb leads Today Gretchen Carlson: Broadsheet for January 2nd'],
#  ['01/02/2018', 'Auto troubles in 2018? 5 trades'],
#  ['01/02/2018', 'How to buy ripple one of the hottest bitcoin competitors'],
#  ['01/03/2018', 'Fugitive Vietnamese tycoon remains in Singapore lawyer says'],
#  ['01/03/2018',
#   'Amazon Google cut speaker prices in market share contest: analysts'],
#  ['01/02/2018',
#   'Heres why cryptocurrencies could soon be facing a big crackdown'],
#  ['05/02/2018',
#   'Google leadership coach: The best way to attract high-performing employees doesnt cost a dime'],
#  ['05/02/2018',
#   'Stocks making the biggest moves premarket: CVS CLX EL GRMN YUM ADP & more'],
#  ['05/02/2018',
#   'Apple CEO Tim Cook takes a victory lap as China revenue rockets'],
#  ['04/03/2018',
#   'Why Hershey Is Investing $500 Million in Its Chocolate Kisses'],
#  ['03/02/2018', 'Cramers game plan: Earnings tainted by Trump tariffs'],
#  ['03/02/2018',
#   'UPDATE 1-Brazil farm exports may benefit from rising U.S.-China trade tensions - official'],
#  ['01/01/2018',
#   'Caterpillars $2 billion tax fight with the IRS could change how US companies do business'],
#  ['05/03/2018',
#   'KKR shares jumps 10% after private equity firm announces structuring change'],
#  ['05/03/2018',
#   'Forget passive investing put your money into the likes of avocados says asset manager'],
#  ['01/02/2018',
#   "China 's large manufacturers are gaining size through overseas deals"],
#  ['02/02/2018', '6 NFL stars who live like theyre broke'],
#  ['02/02/2018',
#   'Art Cashin: The January jobs report hampers an already concerned stock market'],
#  ['01/02/2018',
#   'Tony Robbins: This is the difference between people who stick to resolutions and those who dont'],
#  ['04/03/2018',
#   'SEC Charges $32 Million DJ Khaled-Backed Centra ICO With Fraud'],
#  ['04/03/2018',
#   "Britain wants 'proportionate response to Russia after spy poisoning"],
#  ['01/01/2018',
#   'Jordan royal palace denies rumors about dismissal of princes'],
#  ['04/03/2018',
#   'Fox News Defends Laura Ingraham Over David Hogg Denouncing Advertising Boycott as Intimidation Efforts'],
#  ['05/03/2018',
#   'Mueller focusing sharply on ties between Roger Stone and former Trump campaign official Rick Gates: Sources'],
#  ['05/02/2018', 'Super-rich paying extra for stripped down real estate'],
#  ['05/03/2018',
#   'WSJ Wealth Adviser Briefing: Bitcoin Portfolio Tweaks Big Gulps'],
#  ['05/03/2018',
#   '5 Things to Watch in the April Jobs Report - Real Time Economics - WSJ'],
#  ['03/01/2018',
#   'Mueller builds a case against Russians who leaked Democrat emails during the 2016 election'],
#  ['03/02/2018', 'REIT stocks still very risky to own'],
#  ['03/02/2018', 'There are better methods to solve steel overcapacity'],
#  ['03/02/2018',
#   'Trumps tariffs spark national security concerns over possible strain in relationships with allies'],
#  ['03/02/2018', 'Other US-China tensions may widen if trade spats grow'],
#  ['02/27/2018',
#   'UPDATE 2-Big Corn Big Oil square off in White House biofuels meeting'],
#  ['03/02/2018',
#   'Arthur Laffer: Puerto \'shortsighted fiscal plan totally \'misses the mark"'],
#  ['03/01/2018', 'Markets fear trade war which could bring inflation: Pro'],
#  ['04/01/2018', 'Chinas Rogue Space Station Could Crash to the Earth Tonight'],
#  ['01/01/2018',
#   'Donald Trump Calls for Change in Failing Iran as Economic Protests Turn Fatal'],
#  ['03/02/2018', 'How Gary Cohn got overruled on Trumps tariffs'],
#  ['05/02/2018',
#   'An old Wall Street money manager with $500 billion is moving to Nashville from Manhattan to save money'],
#  ['05/02/2018', 'CFO Moves: MetLife Honeywell International Lloyds of London'],
#  ['05/01/2018',
#   'How one trader is playing the Nasdaq ahead of Apple earnings'],
#  ['02/02/2018', 'Merck posts mixed fourth-quarter results'],
#  ['02/02/2018',
#   'Fire and Fury Media Matters and Secret Empires: A Reading List to the Trump White House'],
#  ['04/03/2018',
#   'Kuroda says the Bank of Japan is talking about an exit from its huge stimulus program'],
#  ['05/01/2018',
#   'Commodities tomorrow: Choppy oil trade till Iran deal figured out'],
#  ['05/02/2018',
#   'Apples definitely become a subscription company says Jim Cramer'],
#  ['04/01/2018', 'Everything That Is Open (and Closed) on Easter Sunday 2018'],
#  ['05/01/2018', 'Apple sold 52.2 million iPhones during the quarter'],
#  ['04/30/2018',
#   'Alibabas Joe Tsai: Were looking long-term beyond \'trade war blip"'],
#  ['04/30/2018',
#   'Twitter doubles down on original shows with NBCUniversal Disney Viacom and more'],
#  ['05/01/2018',
#   'Stocks to Watch: Apple Boeing Pfizer Hasbro Tapestry - MoneyBeat - WSJ'],
#  ['04/30/2018',
#   'Watch CNBCs full interview with Freeport LNG CEO Michael Smith'],
#  ['04/02/2018',
#   'Kevin Carwile Laura Ingraham Justice Department: Broadsheet April 2'],
#  ['01/02/2018',
#   'One big biotech stock looks poised for a breakout in 2018 technician says'],
#  ['01/01/2018',
#   'Chinas central bank will look to keep credit growth in check in 2018'],
#  ['02/03/2018', 'Apple Sets Records With Its Best iPhone Ever'],
#  ['03/01/2018',
#   'For sale: Boone Pickens $250 million ranch. Take a look inside."'],
#  ['03/01/2018', 'Markets quickly move down at the open'],
#  ['03/02/2018',
#   'Colombo Stock Exchange unlikely to see significant downside: chairman'],
#  ['03/31/2018',
#   'Trumps new tax plan could save Amazon roughly $2 billion over the next two years - CNBC'],
#  ['01/02/2018',
#   'This couple bought 40 acres for $9000 years agonow their pot farm is worth millions'],
#  ['01/03/2018',
#   '2 Democrats to be sworn in as senators narrowing the GOPs majority in Congress'],
#  ['02/28/2018', 'Mylan earnings fall with EpiPen sales weak generic prices'],
#  ['05/02/2018',
#   'SpongeBob and Frozen Are Among the Highest-Grossing 2018 Tony Nominees'],
#  ['01/03/2018', 'Macys is about to close more stores'],
#  ['01/03/2018', 'Heres why Amazon may not buy Target'],
#  ['01/03/2018',
#   'Ackmans Pershing Square Valeant to appear in court to discuss an insider trading lawsuit settlement'],
#  ['01/03/2018',
#   'Intel CEO: We believe we have the right fixes for security exploit'],
#  ['04/01/2018', 'China announces its imposing new tariffs on 128 US products'],
#  ['02/01/2018',
#   'I Am a Good Guy Who Made a Bad Decision: Logan Paul Apologizes for Suicide Video on Good Morning America'],
#  ['04/03/2018',
#   'Russia Iran and Turkey struggle to find common ground on Syria'],
#  ['04/02/2018', 'California exports could suffer with China tariffs'],
#  ['04/03/2018',
#   'A key rate for banks has jumped to the highest since the financial crisis but Goldman Sachs isnt worried'],
#  ['04/02/2018',
#   "White House on China tariffs: Tariffs were 'legal and justified to defend steel aluminum industries"],
#  ['04/02/2018',
#   'Amazon executives have reportedly started their headquarters search visits. Heres what theyre asking about'],
#  ['04/02/2018', 'A look at the uncertainty surrounding US soybean exports'],
#  ['03/01/2018',
#   "There will be some 'unintended consequences to proposed US steel aluminum tariffs"],
#  ['03/01/2018',
#   'Cord Cutting Hits Another Record Bashing Cable and Telecom Stocks - Fortune'],
#  ['03/01/2018',
#   'Cramer: Dont be fooledretail REITs stocks are still very risky to own'],
#  ['04/02/2018',
#   'The window to avoid a trade war is closing: Former US ambassador'],
#  ['02/02/2018',
#   'Zuckerberg doesnt want Facebook to edit news because its users can do it better'],
#  ['01/02/2018', 'This investor is still bullish on tech stocks in China'],
#  ['05/01/2018',
#   'Tyson Foods nearly doubles investor money in three years: CEO'],
#  ['01/03/2018',
#   'Four Kosovo MPs get suspended jail terms for tear gas protest'],
#  ['05/01/2018',
#   'Trump looks set to scrap Irans nuclear deal  and this is where itll hurt the most'],
#  ['04/30/2018',
#   'U.S. jury convicts former Autonomy executive of fraud over HP deal'],
#  ['05/01/2018', 'Sugar Low: Commodity Plummets on Surplus'],
#  ['03/31/2018', "Pope baptizes Italy 'migrant hero at Easter Eve service"],
#  ['04/01/2018',
#   'Namibia president says China not colonizing Africa -China state media'],
#  ['02/02/2018',
#   'White House says Trump has declassified GOP surveillance memo'],
#  ['02/02/2018',
#   'Trump blasts FBI and Justice department bosses in a showdown over the Republican memo'],
#  ['02/02/2018',
#   'Fired FBI director James Comey rips \'dishonest and misleading GOP Russia memo  \'Thats it?\'"'],
#  ['02/01/2018',
#   'The average selling price of an iPhone is $100 higher than it was a year ago'],
#  ['02/02/2018',
#   "Amazon CFO: advertising was a 'key contributor to revenue growth in Q4"],
#  ['02/01/2018', 'GoPro misses revenue forecast for holiday quarter'],
#  ['03/01/2018',
#   'CORRECTED-RPT-FOCUS-Bunges coveted Argentina plants lure ADM takeover approach'],
#  ['03/01/2018', 'Brazils economy ended slide in 2017; grew 1 percent'],
#  ['03/01/2018',
#   'WRAPUP 2-Fed chief Powell says no evidence U.S. economy overheating'],
#  ['03/02/2018',
#   'Cramers strategy session: Dont bottom-fish in Walmarts stock just yet'],
#  ['05/01/2018',
#   'Small-business optimism stays near record 53% say conditions look good: CNBC/SurveyMonkey'],
#  ['03/02/2018', "Bosch hires 'internet of things expert from SAP"],
#  ['05/01/2018', 'Trump calls leak of Mueller questions \'disgraceful"'],
#  ['02/04/2018', 'The Best Super Bowl Deals on Pizza Wings and More'],
#  ['02/05/2018',
#   'Amtrak blames freight train operator CSX for its deadly South Carolina crash'],
#  ['04/03/2018', 'How to decipher that college financial aid offer'],
#  ['02/05/2018', 'Stifel CEO on sell-off: Everybody needs to relax'],
#  ['02/05/2018',
#   'Samsungs Lee Jae-yong Has Been Released From Prison After a Successful Appeal'],
#  ['03/01/2018',
#   'A fearsome seven of major tech firms are changing the media industry forever WPP CEO says'],
#  ['01/03/2018',
#   'Watch: White House press secretary Sarah Sanders briefs reporters'],
#  ['03/01/2018', 'The bull case for Nordstrom ahead of earnings'],
#  ['03/01/2018', 'Most Americans say Trump is racist poll finds'],
#  ['03/01/2018',
#   'Beware Qualcomm: Broadcom is used to winning battles with hostility as Amazon knows'],
#  ['03/02/2018',
#   'People keep mistaking the National Restaurant Association for the NRA'],
#  ['02/01/2018',
#   'MItt Romney will make announcement on Utah Senate race on Feb. 15'],
#  ['02/01/2018',
#   "Trump says his State of the Union viewership was 'the highest number in history.' Hes wrong"],
#  ['02/01/2018', '4 things Bill Belichick asks the Patriots to do every day'],
#  ['02/01/2018',
#   "4 'policy cornerstones for Trumps $1.5 trillion infrastructure plan"],
#  ['02/01/2018', 'Google CEO: A.I. is more important than fire or electricity'],
#  ['02/01/2018',
#   'BRIEF-Google Says To Build Additional Data Center In Belgium - Blog'],
#  ['03/02/2018', 'Billionaire CEO Steve Schwarzman: Dont start a business'],
#  ['02/01/2018', 'Lowes confirms plans to pay up to $1000 bonuses'],
#  ['02/02/2018',
#   'Inside the Shakeup at Airbnb: The Startup Loses a CFO Gains a COO - Fortune'],
#  ['02/02/2018', 'Pepsi has been training for the Super Bowl for six months'],
#  ['01/31/2018', 'UPDATE 1-Shell ahead in Mexico oil auction wins five blocks'],
#  ['02/02/2018',
#   'Consumers shopping sprees are giving new life to the Boeing 747'],
#  ['03/02/2018',
#   "Bank of Englands Carney calls for more regulation around the 'speculative mania of cryptocurrencies"],
#  ['03/02/2018',
#   'How DJ Khaled went from broke and in jail to making $24 million working with Jay-Z'],
#  ['03/01/2018',
#   'Best Buy same-store sales surge during the key holiday quarter; shares leap'],
#  ['02/02/2018',
#   'Walmart Sams Club closures spell gains for Costco: JP Morgan'],
#  ['05/01/2018',
#   "'Sell in May and go away doesnt apply this year market bull Tony Dwyer says"],
#  ['04/30/2018', 'SEC Wants Boards Views on Contested Shareholder Proposals'],
#  ['05/01/2018',
#   'Watch Steve Jobs defend his commitment to Apple on CNBC in 1997'],
#  ['05/01/2018',
#   'Marathon-Andeavor merger checks the boxes where it counts: Texas Mexico and the high seas'],
#  ['02/02/2018',
#   "Minneapolis Feds Kashkari: Strong January jobs data show 'one of the first signs of long-awaited wage growth"],
#  ['04/02/2018', 'Term Sheet  Monday April 3'],
#  ['02/02/2018',
#   'UPDATE 3-Exxon profit misses Street on refining chemical weakness - Reuters'],
#  ['01/04/2018', 'Bull market is very much alive: BMOs Brian Belski'],
#  ['01/03/2018',
#   'UPDATE 1-Vale is negotiating BHP exit from Samarco venture -sourceGG'],
#  ['02/01/2018',
#   'Trump is expected to allow House Republicans to release contentious memo over FBI objections'],
#  ['02/01/2018',
#   'US jobless claims unexpectedly fall as job market strengthens'],
#  ['02/01/2018',
#   'Fresh from peacock incident United sets stricter standards for emotional support animals'],
#  ['02/02/2018',
#   'NFL concussions strategy for 2018 Super Bowl includes a roster change'],
#  ['02/02/2018',
#   'Cramer to Google-parent Alphabet: I want the Super Bowl of earnings'],
#  ['02/02/2018', 'Apple vows to cut its $163 billion in net cash to \'zero"'],
#  ['04/01/2018',
#   'Cloudflare Announces a Faster More Private Internet Directory'],
#  ['05/01/2018', 'How I Empower the Introverts on My Staff'],
#  ['03/02/2018',
#   'BlackRock says its time to take action on guns may use voting power to influence'],
#  ['03/02/2018',
#   'UPDATE 1-Euro zone bonds sailing into weekend of key risk events - Reuters'],
#  ['03/02/2018',
#   'The dangerous new dance as corporations balance business and social risk'],
#  ['03/01/2018', 'Cramer: Worries about the Trump tariffs are far too extreme'],
#  ['03/01/2018',
#   'Worlds largest beer maker says profits have surged as its Brazil market rebounds'],
#  ['01/02/2018', 'US energy infrastructure firms show good value'],
#  ['01/05/2018', "Cramer: The US-China 'trade war could explode in 2018"],
#  ['02/01/2018',
#   'An Animated Super Mario Bros. Movie Is Coming and the Minions Studio Will Make It'],
#  ['02/01/2018',
#   'Pharma trade group urges appeals court to save Allergans Restasis patents - Reuters'],
#  ['02/01/2018',
#   'Italy\\\'s Enel: "no interest in powering cryptocurrency miners'],
#  ['02/01/2018',
#   'Brenda Fitzgerald Larry Nassar Walmart: Broadsheet for Feb. 1'],
#  ['02/01/2018',
#   'Airbnb loses CFO Laurence Tosi company says it wont go public this year'],
#  ['01/03/2018', "Italys Northern League pledges to put right 'error of euro"],
#  ['01/03/2018',
#   'Netflix starts 2018 off with a bangand one technician sees the stock surging even higher'],
#  ['01/03/2018', 'Petrobras agrees to pay $2.95B to settle case in the US'],
#  ['01/03/2018',
#   'With tax law not positive for housing top analyst finds value away from homebuilders'],
#  ['04/03/2018',
#   "Amazon could 'take Google to the cleaners in retail search with a $20 billion ad business analyst says"],
#  ['04/03/2018',
#   'Billionaire Virgin Hyperloop One Director Arrested on Fraud and Embezzlement Charges'],
#  ['01/03/2018', 'Spotify makes confidential filing for U.S. IPO: source'],
#  ['01/02/2018',
#   'EMERGING MARKETS-Latam currencies stocks rally at start of 2018'],
#  ['01/03/2018',
#   'Mobileye deal boosts Israeli high-tech exits to $23 billion in 2017'],
#  ['02/01/2018', 'Cuba hands note of protest to U.S. over internet task force'],
#  ['02/01/2018', 'GoPro set to report after the close'],
#  ['02/01/2018',
#   'Cigna CEO sees Amazon-led employee health initiative as an \'opportunity"'],
#  ['02/01/2018',
#   'Maldives top court orders retrial of ex-president opposition leaders'],
#  ['02/02/2018',
#   'Alphabet downgraded on rising competition from Amazon in ads cloud computing'],
#  ['02/01/2018',
#   'Mastercard profit tops Street on holiday shopping rush; shares hit record'],
#  ['05/03/2018',
#   'Iran foreign minister says the country will not renegotiate its nuclear deal'],
#  ['05/03/2018', 'France and Germany at Loggerheads Over Trump Tariff Plan'],
#  ['05/02/2018', 'Hulu surpasses 20 million US subscribers'],
#  ['05/02/2018', 'What this WWE billionaire learned from bankruptcy'],
#  ['03/07/2018', "Oil flashing a sell sign for stocks?'"],
#  ['02/01/2018',
#   'GOP lawmakers put their medical skills to work after a deadly train crash'],
#  ['03/01/2018', 'Steel stocks rise ahead of potential trade announcement'],
#  ['01/05/2018',
#   'China to further improve yuan cross-border transactions to facilitate trade'],
#  ['01/05/2018', "South Korea on alert for 'US bullying during trade talks"],
#  ['01/05/2018',
#   'Rising commodity prices due to investment increase: Commerzbank'],
#  ['01/05/2018',
#   'Tax reform bonuses to lift retail stocks Barclays says upgrades Target Lowes'],
#  ['01/05/2018',
#   'Retail industry was reason behind weak jobs report but construction jobs still booming'],
#  ['01/05/2018',
#   'Pot stocks take a hit but market watchers say theyll end in the green'],
#  ['01/04/2018', 'Your first trade for Thursday January 4'],
#  ['01/04/2018',
#   'Half-ton butter sculpture unveiled at Pennsylvania Farm Show'],
#  ['03/01/2018',
#   'US steel aluminum execs are headed to the White House for a possible announcement on trade'],
#  ['03/02/2018', 'Soybeans are one way China could respond to metal tariffs'],
#  ['05/02/2018',
#   'Sprint names Michel Combes as CEO and Marcelo Claure as executive chairman'],
#  ['01/03/2018',
#   'Richard Bransons simple trick to come up with an idea for a successful business'],
#  ['03/02/2018', 'UPDATE 2-Microchip to buy Microsemi for about $8.35 bln'],
#  ['01/03/2018',
#   'UPDATE 1-Petrobras to pay $2.95 bln to settle U.S. class action over corruption'],
#  ['02/02/2018',
#   'Cramers guide to the sell-off: \'Its not the end of the world"'],
#  ['04/30/2018', 'What to buy on a weak tape: 4 trades'],
#  ['05/01/2018', '"Fast Money final trades: C SNAP and more'],
#  ['04/01/2018', 'Spielbergs Ready Player One Debuts at No. 1 at Box Office'],
#  ['02/01/2018',
#   'Chipotle downgraded to sell by UBS citing worse brand perception than when food safety crisis began'],
#  ['02/01/2018',
#   'Stocks making the biggest moves premarket: DWDP BABA BX UPS FB MSFT QCOM & more'],
#  ['02/01/2018', 'Heres why one bitcoin bear is turning bullish'],
#  ['02/01/2018', 'Lowes bonuses: Heres what employees will receive'],
#  ['05/02/2018',
#   'The Morning Ledger: U.S. Companies Squeezed by Rising Commodity Prices'],
#  ['05/02/2018', 'Amazon gallops into the Kentucky Derby'],
#  ['05/02/2018',
#   'WSJ City: Trumps Trade Agenda Brings Heightened Tensions Apple Flexes Its Financial Muscles'],
#  ['05/02/2018', 'Cramer: Snaps conference call was like SNL parody'],
#  ['05/02/2018', 'Fed holds rates steady but points to higher inflation'],
#  ['05/02/2018',
#   'A Tight Rein on Finances Helps Bosch Keep Up with Rivals - CFO Journal. - WSJ'],
#  ['05/02/2018',
#   "Four of the worlds largest automakers want to bring the 'blockchain to your car"],
#  ['04/02/2018',
#   'How Americas Biggest Broadcaster Is Using Local News to Boost Trumps Agenda'],
#  ['04/30/2018', 'Cloud Revenues See Sharper Gains - CIO Journal. - WSJ'],
#  ['04/02/2018',
#   'Chinas Space Station Wasnt the End. Three More Satellites Expected to Crash to Earth This Week'],
#  ['02/01/2018',
#   "'Disrgraced : Pelosi demands removal of Rep. Nunes as House Intelligence chair over Russian probe"],
#  ['01/31/2018',
#   'Ebay posts loss for holiday quarter as it books $3.1 billion tax charge'],
#  ['03/01/2018', 'Kohls earnings beat on the top and bottom lines'],
#  ['03/01/2018', "MAG: Nuns exploited for cheap Church labor...'"],
#  ['03/01/2018',
#   'Huawei distances itself from CEO comments after he goes off-script and rages over US snub'],
#  ['03/01/2018',
#   'UK rules out holding second part of inquiry into press ethics'],
#  ['03/01/2018',
#   'Best Buy posts higher comparable sales during key holiday quarter'],
#  ['05/02/2018',
#   'Credit Suisse: Investors are worrying too much and are going to miss out on big market upside ahead'],
#  ['05/02/2018',
#   'Trump replacing Ty Cobb with Clinton impeachment lawyer Emmet Flood: NYT'],
#  ['05/02/2018', 'Think Youre Too Old to Found a Startup? Think Again'],
#  ['05/02/2018', 'China Iron-Ore Futures Open to Outside World'],
#  ['05/03/2018', 'Agriculture is a good niche sector says investor'],
#  ['05/03/2018',
#   'After a year of Macron start-up hum grows at Pariss Station F'],
#  ['05/03/2018',
#   'Activision Blizzard reports 15.7 percent rise in adjusted revenue'],
#  ['05/03/2018',
#   'Here are highlights of Elon Musks strange Tesla earnings call: \'Theyre killing me"'],
#  ['05/03/2018', 'Problems Near Far Ram Hong Kong Stocks'],
#  ['01/03/2018',
#   "Bannon calls Trump Jr. meeting with Russians 'treasonous: book"],
#  ['01/03/2018',
#   'Oil prices are poised to fall because theres little left to do but sell'],
#  ['01/03/2018',
#   'If you invested $1000 in Disney 10 years ago heres what youd have now'],
#  ['01/03/2018',
#   'Big Tech Sends Nasdaq to New Record High: CEO Daily for January 3 2018'],
#  ['05/02/2018',
#   'Square drops 6 percent after issuing a disappointing forecast'],
#  ['01/04/2018', 'See Harrowing Footage of Icy Floods Along East Coast'],
#  ['01/05/2018',
#   'Colbert and Noah are all set for Trumps Most dishonest and corrupt media awards'],
#  ['03/02/2018',
#   "Brazil threatens 'action to protect interests after Trump tariff move"],
#  ['03/01/2018', 'Oil and gas sectors drop on steel and aluminum tariff news'],
#  ['03/02/2018', 'Why companies with more female executives make more money'],
#  ['02/28/2018',
#   'US Ag Secretary seeks to calm farmers after Trump biofuel talks'],
#  ['04/03/2018', 'raceAhead: Eliminating Bias Through Checklists'],
#  ['01/06/2018',
#   'Forget Face ID. The Future of Secure Authentication Is Your Voice'],
#  ['04/30/2018',
#   "'A competitor will be removed from the market if Sprint and T-Mobile are allowed to merge: Analyst"],
#  ['01/03/2018',
#   'Brazilian agency requires Apple to inform consumers on batteries'],
#  ['01/04/2018',
#   'This Company Is Set to Become a Driving Force Behind Fully Autonomous Vehicles'],
#  ['01/04/2018',
#   "Cramer: AMDs CEO will 'take advantage of Intels security flaw fallout"],
#  ['01/04/2018', 'Tesla guidance disappoints'],
#  ['01/05/2018',
#   'Trump-Bannon Feud Is the Death of Truth: CEO Daily for January 5 2018'],
#  ['01/05/2018',
#   'Justice Dept launches new Clinton Foundation probe: The Hill'],
#  ['03/01/2018',
#   'HUD chief Ben Carson moves to cancel order for $31561 executive dining room set'],
#  ['01/05/2018',
#   'The countrys most innovative bar is serving a $27 cocktail packaged in a pillow of bagel air'],
#  ['01/05/2018', 'Spotify reaches 70 million subscribers'],
#  ['01/05/2018',
#   'Winter storm forces worlds largest passenger jet to divert to small New York airport'],
#  ['01/05/2018',
#   'Trumps offshore drilling plan could help the Democrats says expert'],
#  ['01/04/2018',
#   'Cramer pinpoints stocks that are feeding the market in \'beast mode"'],
#  ['02/01/2018', 'Apples cash pile hits $285.1 billion a record'],
#  ['02/01/2018',
#   'Ryan says progress on spending talks sees another another stopgap measure'],
#  ['04/02/2018',
#   'Overall growth profile for China looks quite stable: Economist'],
#  ['01/05/2018',
#   'Planet Fitness CEO says scale has become ultimate \'competitive advantage"'],
#  ['01/05/2018',
#   'Heres what to expect at CES this year: Smart homes robots TVs and more'],
#  ['01/05/2018', 'China wont be prioritizing growth this year economist says'],
#  ['01/06/2018',
#   'E. coli outbreak linked to romaine lettuce frustrates produce industry'],
#  ['01/06/2018',
#   'Google Microsoft and Amazons Trade Group Joining Net Neutrality Court Challenge'],
#  ['01/04/2018',
#   'BRIEF-Google Says Its Project Zero Security Team Last Year Discovered Vulnerability Affecting Modern Microprocessors - Blog'],
#  ['04/04/2018',
#   'In Africa scant data protection leaves internet users exposed'],
#  ['03/01/2018',
#   "REFILE-UPDATE 1-Four Fed rate hikes this year would be 'gradual -Dudley"],
#  ['01/02/2018', 'Amazon could buy Target in 2018: Gene Munster'],
#  ['01/02/2018',
#   'GRAINS-Cold concerns spark U.S. wheat futures rally; corn firm; soy weak'],
#  ['01/03/2018',
#   'Are You Eating Sustainable Fish? Blockchain May Provide the Answer'],
#  ['01/04/2018',
#   'This bull market will continue to all-time highs: CFRAs Sam Stovall'],
#  ['01/04/2018', 'Dow Hits 25000: Heres Why It Matters'],
#  ['02/01/2018', 'Heres who is benefiting from Chipotles food safety woes'],
#  ['01/05/2018', 'The Final Call: Biotech & more'],
#  ['03/01/2018',
#   "Sessions pushes back on Trumps criticism over his 'disgraceful handling of the FBI"],
#  ['03/01/2018',
#   'This popular bitcoin strategy is flawed and hurts investors analyst Nick Colas warns'],
#  ['01/03/2018', 'Chinas WeChat denies that its storing users chats'],
#  ['01/04/2018', 'Irans Protests: Whats Next?"'],
#  ['01/04/2018', 'How to short bitcoin'],
#  ['01/04/2018',
#   'UPDATE 1-Brazils Santander rural loans rise to $4 bln in 2017'],
#  ['01/04/2018',
#   'Brazil 2017 home prices fall for first time in at least a decade'],
#  ['01/03/2018',
#   'UPDATE 5-Petrobras to pay $2.95 bln to settle U.S. corruption lawsuit'],
#  ['01/03/2018', 'Vale is negotiating BHP exit from Samarco venture -sourceGG'],
#  ['01/05/2018',
#   'Solid US job growth expected in December with wages seen rising'],
#  ['01/05/2018', 'The most popular free apps to keep you healthy in 2018'],
#  ['01/05/2018',
#   'raceAhead: Zuckerbergs New Resolve Genocide Spurred on By Facebook Posts and Toxic Femininity'],
#  ['03/01/2018',
#   'Stocks making the biggest moves premarket: BBY KSS HOG BID NWL WMT CRM & more'],
#  ['03/01/2018',
#   'As tech rallies on market watchers say Netflix and Micron are the two names to buy'],
#  ['02/02/2018',
#   'Heres what Wall Street analysts thought of Apples earnings report'],
#  ['01/05/2018',
#   'Time for a sober reassessment of the markets: NYTs Jim Stewart'],
#  ['01/05/2018', "DECEMBER JOBS: +148K...'"],
#  ['01/06/2018', 'Last years S&P 500 losers could be prime for speculation'],
#  ['01/05/2018',
#   'Cramer: The S&P 500s winners for 2017 could still have room to run this year'],
#  ['01/04/2018', 'Art Cashin on Dow 25000'],
#  ['01/04/2018',
#   'Weinstein Company close to selling itself for less than $500 million: Report'],
#  ['01/04/2018',
#   'Another tiny digital coin leaps into the top 10 cryptocurrencies'],
#  ['03/07/2018', 'China ETFs market warning'],
#  ['01/05/2018',
#   'Self-made millionaire: Once you have some money heres what to do'],
#  ['01/05/2018',
#   'Defending his bombshell Trump book Wolff says people describe the president like a child'],
#  ['05/03/2018',
# ...
#  ['04/05/2018', "Jamie Dimon backs Trumps 'legitimate complaints over trade"],
#  ['01/04/2018',
#   'A record start to the year as the Dow soars past 25K heres what traders are buying'],
#  ['01/05/2018',
#   'Trump had lawyer urge Attorney General Jeff Sessions against Russia recusal'],
#  ['04/05/2018',
#   'Tesla production briefly halted by paint shop fire in Fremont factory'],
#  ['04/05/2018',
#   'U.N. rights watchdog urges Hungary to halt hate speech protect refugees'],
#  ['01/04/2018',
#   'FCC Chairman Ajit Pai canceled his appearance at CES because of death threats'],
#  ['01/05/2018',
#   'Global debt level hits $233 trillion record high in the third quarter of 2017 IIF says'],
#  ['01/05/2018', 'Aerospace and defense ETFs take off'],
#  ['02/02/2018', 'US factory orders post fifth straight monthly increase'],
#  ['02/02/2018', 'Black unemployment spikes to 7.7%, up from record low'],
#  ['02/02/2018',
#   "Merrill Lynch 'sell signal triggered as market faces more losses ahead"],
#  ['05/02/2018',
#   'Heres one wedding gift Meghan Markle wont want: A bigger tax bill'],
#  ['05/02/2018',
#   'Heres what every major Wall Street analyst had to say about Apples earnings'],
#  ['01/08/2018',
#   'Heres what Trump is going to talk about in his first major speech since tax reform passed'],
#  ['04/04/2018',
#   'We must retaliate when people damage our interests says Chinas vice finance minister'],
#  ['02/02/2018',
#   'Cramer on Feds Wells Fargo move: I dont think bank stocks could get a worse piece of news'],
#  ['01/07/2018',
#   'Chinas digital push in insurance is widening the playing field'],
#  ['02/06/2018',
#   'Oil prices extend losses falling with broader financial markets after a comeback effort fails'],
#  ['03/01/2018', 'Cramers lightning round: Dont touch the stock of Albemarle'],
#  ['03/02/2018', 'Ford warns Trump metal tariffs may hike commodity prices'],
#  ['05/02/2018', 'Brexit & Beyond: Eurozone Economy Stumbles in First Quarter'],
#  ['05/02/2018',
#   'The Amazon effect could potentially leave all Americans neighborless'],
#  ['04/07/2018',
#   "US farmers in 'precarious position with China as trade war fears escalate"],
#  ['02/02/2018',
#   'Federal Reserve orders Wells Fargo to replace four board members restricts growth because of \'consumer abuses"'],
#  ['03/03/2018', 'Israeli troops kill Palestinian near Gaza border: officials'],
#  ['03/02/2018',
#   'Oscar-nominee Timothe Chalamets 1st big splurge: Knicks tickets'],
#  ['03/01/2018',
#   'Maria Contreras-Sweet says has clinched deal for Weinstein Co assets'],
#  ['03/02/2018',
#   'Georgia punishing Delta over NRA stance wont help Atlantas bid for Amazon HQ2'],
#  ['03/02/2018',
#   'Larry Kudlow: Im urging Trump advisor Gary Cohn to stay at the White House'],
#  ['03/02/2018',
#   'Chinas alleged intellectual property theft a bigger threat to market than tariffs: Analyst'],
#  ['04/30/2018',
#   "Treasury Secretary Mnuchin: 'No question Trump sanctions brought North Korea to negotiating table"],
#  ['02/05/2018', 'Tech investor: \'People are panicking for no reason"'],
#  ['03/02/2018',
#   "Americans 'are going to pay the price for Trump tariffs former Obama trade advisor warns"],
#  ['02/06/2018',
#   'Trump economic advisor Kevin Hassett: Tax cut savings will make their way into the stock market'],
#  ['02/06/2018', 'Your first trade for Tuesday February 6'],
#  ['04/05/2018',
#   "FANG stocks are in 'fairyland and any bounce back could be 'fragile' analyst warns"],
#  ['04/05/2018',
#   'EXCLUSIVE-Yellen gets post-Fed payday in private meetings with Wall St. elite'],
#  ['04/05/2018',
#   "JP Morgan strategist sees stocks up 10% by the end of 2018 on 'strong corporate profits"],
#  ['04/05/2018', 'US trade deficit rises to near 9-year high'],
#  ['04/05/2018', 'US reportedly plans to sanction Russian oligarchs this week'],
#  ['04/05/2018', 'U.S. Unemployment Claims Rise to Highest in Nearly 3 Months'],
#  ['04/05/2018', 'Heres how to find what Amazon knows about you'],
#  ['01/05/2018',
#   'Trumps first year: White House policies help boost manufacturing sector'],
#  ['03/08/2018', "CNBC reporter escorted out of 'steel-free town in China"],
#  ['03/08/2018',
#   'Former Trump aide interviewed by House committee over Russia'],
#  ['03/07/2018',
#   'Cramers strategy session: What itll take for me to come around on GE'],
#  ['03/07/2018',
#   'GRAINS-Prices tick lower as USDA report trade risks prompt caution'],
#  ['02/02/2018', 'Now is a great time to land a new job. Heres how'],
#  ['02/02/2018', 'This couple has made millions selling homemade ukuleles'],
#  ['02/02/2018', 'Key dates in Brexit process - Reuters'],
#  ['02/02/2018', 'Melania Trump Nikki Haley Kate Upton: Broadsheet for Feb. 2'],
#  ['02/02/2018',
#   'Apple gets two downgrades due to dramatically slowing iPhone X demand'],
#  ['02/28/2018', "Xi Jinping has 'a big plan for China"],
#  ['02/27/2018',
#   'UPDATE 3-Big Corn Big Oil square off in White House biofuels meeting'],
#  ['02/27/2018',
#   'GRAINS-Wheat rises to seven-month high on low U.S. crop ratings'],
#  ['03/02/2018',
#   'Energy has best chance of bringing angry NAFTA nations back to their senses in a trade war'],
#  ['03/02/2018',
#   'Toyota venture to spend $2.8 billion to develop self-driving technology'],
#  ['03/01/2018',
#   'TREASURIES-U.S. yields fall as tariffs trump Powells less rosy view'],
#  ['05/02/2018',
#   'Investors should not be worried by dip in iPhone sales says BTIG analyst'],
#  ['01/07/2018', 'China currency outflows have eased with a weaker dollar'],
#  ['01/07/2018', "UBS has seen a 'more open field for asset managers in China"],
#  ['05/02/2018',
#   'Guggenheim investment chief sees stocks rising 20% more before a recession-fueled sell-off'],
#  ['03/02/2018',
#   'A tiny Nebraska startup won Trumps first border wall contract  and thats raising questions'],
#  ['03/02/2018',
#   'Not all Europeans hate Trumps tariff policy Italys far-right PM candidate loves it'],
#  ['03/02/2018',
#   'Attack on French embassy army in Burkina Faso kills eight - Reuters'],
#  ['04/05/2018', 'How much you need to save to afford to buy a home'],
#  ['04/05/2018',
#   'Cyclist fired for flipping off the Presidents motorcade is suing her former employer'],
#  ['04/05/2018', "Migrants keep moving NORTH...'"],
#  ['04/05/2018',
#   'San Francisco sues U.S. attorney general over repealed civil rights memos'],
#  ['04/03/2018', 'China Hong Kong stocks down amid resurgent trade war fears'],
#  ['04/04/2018',
#   'Turkey says Russian S-400 missile delivery brought forward to July 2019'],
#  ['04/04/2018',
#   'Trump to order National Guard deployment to border with Mexico'],
#  ['04/03/2018',
#   'Cramer: I helped investors through the 2010 flash crash by following one key rule'],
#  ['04/05/2018',
#   'MoviePass Just Bought Moviefone. Heres What It Means for Moviegoers'],
#  ['04/04/2018',
#   'Cramer explains why investing for kids can have a huge payoff'],
#  ['03/01/2018',
#   'Treasury Secretary Mnuchin tells UCLA it cant show footage of his event after being heckled booed'],
#  ['01/06/2018', 'Last years S&P 500 winners could still have room to run'],
#  ['03/02/2018',
#   "Delta CEO says 'Our values are not for sale' after Georgia lawmakers drop tax break"],
#  ['01/05/2018',
#   'Goldman says Nvidia  best chip stock last year  headed for another big year'],
#  ['01/04/2018',
#   'Dominion CEO bullish on latest deal despite slumping stock: \'Were investing for the long term in South Carolina"'],
#  ['04/04/2018',
#   "U.S. must 'mitigate trade damage on American farmers -senator"],
#  ['04/05/2018', 'US Diplomat Expulsions Deepen Divisions With Russia'],
#  ['04/05/2018',
#   'Germanys Merkel plans to visit Trump as trade deadline looms: Bild'],
#  ['04/05/2018',
#   "Trump budget director Mulvaney: 'MAGAnomics is working and defying critics"],
#  ['04/05/2018',
#   'Trump dives into heated West Virginia Senate race with swipes at Democratic Sen. Joe Manchin'],
#  ['04/04/2018',
#   'CBS bid for Viacom was immediately rejected sources tell CNBC'],
#  ['01/12/2018',
#   'Whoops analyst downgrades Facebook stock hours after recommending it as shares tanked'],
#  ['04/05/2018',
#   'HR Confidential: I hired him without a background check. Then he stole his colleagues identities'],
#  ['04/04/2018',
#   'UPDATE 1-Brazil soy exporters set to win big from U.S.-China trade spat'],
#  ['04/04/2018',
#   'Once-hot semi stocks are in a correction. Heres why some are shrugging off the pain'],
#  ['04/04/2018',
#   'Tariffs on appliances electronics would hit consumers: U.S. retailers'],
#  ['02/02/2018',
#   'Super Bowl-bound Patriots owner Bob Kraft shares an 18-year-old ritual he has with Tom Brady'],
#  ['02/02/2018',
#   'Oil from sunken Iranian tanker may have reached Japan shores: Coast Guard'],
#  ['01/03/2018',
#   'Asia looks set to open in positive territory after S&P 500 cracks 2700'],
#  ['01/03/2018',
#   'UPDATE 1-Chinas Didi Chuxing buys control of Brazils 99 ride-hailing app'],
#  ['04/05/2018',
#   '3 things you can do to see if you and your future boss are compatible'],
#  ['03/03/2018',
#   'Syrian government makes Ghouta gains; Turkey steps up Afrin attack'],
#  ['03/01/2018',
#   'WRAPUP 1-Feds Powell says no evidence U.S. economy overheating'],
#  ['05/01/2018',
#   'U.K. to Mandate Public Company Registers in Overseas Territories'],
#  ['05/02/2018', 'Technology companies are driving a capital spending surge'],
#  ['02/02/2018',
#   'Cryptocurrency Traders Lose $115 Billion in 24 Hours as Bitcoin Bloodbath Continues'],
#  ['05/02/2018',
#   'How Trump Unites and Divides the Parties - Washington Wire - WSJ'],
#  ['05/02/2018',
#   'Top Wharton professor Adam Grant: How you can find meaning in your work life'],
#  ['04/04/2018',
#   'CEO of controversial crypto company Longfin blames short sellers for stock plunge'],
#  ['04/04/2018',
#   'Brazil soy exporters set to win big from U.S.-China trade spat'],
#  ['04/05/2018',
#   '3100 Google employees to CEO Sundar Pichai: Google should not be in the business of war'],
#  ['04/04/2018',
#   'Cramer: Yes disinterested teens can actually make the best investors'],
#  ['04/05/2018',
#   'Trump seems less concerned about stock markets as he tries to deliver to his base'],
#  ['02/02/2018',
#   'UPDATE 2-Boeing Embraer consider creating 3rd firm to win Brazil nod -source'],
#  ['02/05/2018',
#   'Apples $1000 iPhone X has a bug that is preventing users from answering calls'],
#  ['03/05/2018',
#   'Caterpillar and Boeings next moves may determine the Dows future technician says'],
#  ['02/05/2018', 'Experts everywhere tell you to buy a hometheyre wrong'],
#  ['04/04/2018',
#   'More Tariffs Apple AI Sorrell Probe: CEO Daily for April 4 2018'],
#  ['02/05/2018', 'Here are some stocks you can buy on the dip: Technician'],
#  ['02/05/2018', 'The market is droppingheres what you should do'],
#  ['02/06/2018',
#   'Fidelity says it saw no panic among its customers and more buying than selling during the plunge'],
#  ['02/05/2018', 'Lululemon CEO Exits Due to Poor Conduct'],
#  ['02/02/2018',
#   'We asked the Internet who should run Amazons new health consortium'],
#  ['01/31/2018', 'UPDATE 3-Shell ahead in Mexico oil auction wins five blocks'],
#  ['02/02/2018',
#   'Facebooks rising ad prices are more than making up for slowing growth'],
#  ['02/01/2018',
#   'The Wall Street Journal: Tesla sells $546 million of bonds to raise cash for production ramp-up'],
#  ['02/01/2018', 'Alphabet to report earnings after the bell'],
#  ['03/02/2018',
#   'Spring gas prices are expected to be 17 percent higher. Heres how to save'],
#  ['03/02/2018',
#   "China would take 'measured steps if trade spats with the US escalate"],
#  ['04/05/2018',
#   'Russian historian who exposed Stalins crimes cleared of child pornography: TASS'],
#  ['01/05/2018',
#   'Trump-Bannon fallout could threaten Republicans in midterm elections analysts say'],
#  ['02/03/2018',
#   'Look out below: The US dollars dive may get even steeper a currency expert says'],
#  ['02/02/2018', 'One key event that crypto traders are watching next week'],
#  ['03/02/2018',
#   'REFILE-UPDATE 2-Euro zone bonds sailing into weekend of key risk events - Reuters'],
#  ['02/02/2018',
#   '19-year-old bitcoin millionaire: You should invest this much of your income in cryptocurrencies'],
#  ['05/01/2018', 'Facebook to allow users to clear browsing history'],
#  ['05/01/2018',
#   'Manufacturing activity continues to decline in April; construction spending stumbles in March'],
#  ['05/01/2018', 'Asian stocks poised for slight gains as dollar advances'],
#  ['05/02/2018',
#   'Amazon is reportedly offering discounts to retailers for using its payment service'],
#  ['05/02/2018',
#   'Watch Elon Musk promise back in 2006 that SpaceX will be the top rocket company'],
#  ['05/02/2018', 'Most Popular ETF Bet in April: Short-Term Debt'],
#  ['02/03/2018',
#   'UPDATE 3-Germanys potential coalition partners agree on energy wrangle over health'],
#  ['05/02/2018',
#   "Trump threatens to 'get involved with Justice Department over 'rigged system on Russia Clinton"],
#  ['04/30/2018', "Meet the man who 'invented the #hashtag"],
#  ['04/06/2018',
#   'Amid all the volatility two retail stocks are surging  and traders still see them as a bargain'],
#  ['04/06/2018',
#   'Inside the $50 million Hamptons estate that was once a convent for Catholic nuns'],
#  ['04/06/2018',
#   'Trump touts falling aluminum prices as reason to not fear tariffs'],
#  ['04/06/2018', 'Heres what people would do with a $10000 windfall'],
#  ['02/06/2018', 'Vietnam jails environmental blogger for 14 years'],
#  ['02/06/2018', 'Why the sell-off makes sense'],
#  ['02/06/2018',
#   'Feds Bullard says job market strength may not lead to higher inflation'],
#  ['03/03/2018',
#   'Trump tariffs could emerge as a black swan event for stocks long-time bull Jeff Saut warns'],
#  ['02/06/2018',
#   'One chip stock is bucking the global sell-off in the market  Micron'],
#  ['04/04/2018',
#   'Nightmare Bacteria Are a Real and Growing Threat in the U.S., CDC Warns'],
#  ['03/02/2018', 'U.S. announces 10 indictments in international fraud scheme'],
#  ['04/04/2018',
#   "Trump: 'We are not in a trade war with China' we lost that war many years ago"],
#  ['04/04/2018',
#   'Watch: White House briefs media amid concerns about Trumps proposed tariffs'],
#  ['03/02/2018',
#   "'Its very hard to understand what has gotten into the president: Trade expert on Trumps tariffs"],
#  ['02/05/2018',
#   'Trump administration pulls back from a full-scale probe of massive Equifax data breach'],
#  ['02/05/2018',
#   "Facebook seeks 'extra-terrestrial product manager as it plans to deliver internet from the sky"],
#  ['05/02/2018',
#   "Cryptocurrencies heading for a 90 percent correction in 'mass market wipe out' investment bank warns"],
#  ['05/02/2018',
#   'Mays latest Brexit headache - a customs deal with the EU - Reuters'],
#  ['05/02/2018',
#   'Peppa Pig Is Reportedly the Latest Target of Chinas Internet Censorship Efforts'],
#  ['03/02/2018',
#   'Amazon will collect sales tax for shipments to Pennsylvania as states seek to recoup billions'],
#  ['02/05/2018',
#   'White House says Trumps legal team supports a second special counsel to probe FBI DOJ'],
#  ['03/01/2018',
#   'Trade war threat stokes inflation concerns Allianz analyst says'],
#  ['02/28/2018',
#   "Global equity markets are in 'a downward spiral led by the US"],
#  ['03/02/2018',
#   'US Steel downgraded by Bank of America on tariff retaliation fear'],
#  ['01/09/2018', 'Pot bitcoin Micron all speculative'],
#  ['04/03/2018', 'Century Aluminum CEO on the tariff impact'],
#  ['04/04/2018',
#   'Heres the full list of US products that China is planning to hit with tariffs'],
#  ['04/30/2018',
#   'ANALYSIS-Brazil ethanol sales to Japan to sputter as Tokyo woos Trump'],
#  ['05/01/2018',
#   'A $14000 cholesterol drug gets a price cut as Regeneron Sanofi strike deal with Express Scripts'],
#  ['05/01/2018',
#   'Retire to these overseas destinations to make the most of your nest egg'],
#  ['02/06/2018', 'Coach owner Tapestrys sales top Wall Street estimates'],
#  ['02/05/2018', 'Cramers sell-off strategy: Spotting the markets bottom'],
#  ['02/05/2018',
#   'The Wall Street Journal: As markets tumbled investment firms websites suffered outages'],
#  ...]

# %%
#Pre-processing news headlines 
features = news_headlines.iloc[:,1].values
processed_features = []
for sentence in range(0, len(features)):
    # Remove all the special characters
    processed_feature = re.sub(r'\W', ' ', str(features[sentence]))
     # remove all single characters
    processed_feature= re.sub(r'\s+[a-zA-Z]\s+', ' ', processed_feature)
     # Substituting multiple spaces with single space
    processed_feature = re.sub(r'\s+', ' ', processed_feature, flags=re.I)
     # Converting to Lowercase
    processed_feature = processed_feature.lower()
    processed_features.append(processed_feature)

# %%
processed_features_arr = np.asarray(processed_features)
processed_features_arr
# Out:
# array(['mexican presidential front runner hits back at trump nafta threat blasts pinata treatment ',
#        'cramer reflects on how trump actions are fueling the beast market rally ',
#        'the wall street journal peter thiels vc firm has made monster bet on bitcoin ',
#        ...,
#        'the klein law firm announces commencement of class action filed on behalf of super micro computer inc shareholders and lead plaintiff deadline of april 9 2018 ',
#        'trump says won build california border wall until whole wall is approved ',
#        'sky is the limit in battle for sky '], dtype='<U251')

# %%
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords

#Specifying module parameter
stemmer = SnowballStemmer('english')
tokenizer = RegexpTokenizer(r'[a-zA-Z\']+')

#defining function for tokenizing input text
def tokenize(text):
    return [stemmer.stem(word) for word in tokenizer.tokenize(text.lower()) if not word in set(stopwords.words('english'))]

# %%
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import TfidfVectorizer 
punc = ['.', ',', '"', "'", '?', '!', ':', ';', '(', ')', '[', ']',  '{', '}', "%"]

#Vectorizing headlines array 
stop_words = text.ENGLISH_STOP_WORDS.union(punc)
vectorizer = TfidfVectorizer(stop_words = stop_words, tokenizer = tokenize)        
X = vectorizer.fit_transform(processed_features_arr)

# %%
#Extracting word features and number of features
word_features = vectorizer.get_feature_names()
print(len(word_features))
print(word_features[:100])
# Out:
# 27742
# ['aa', 'aaa', 'aac', 'aadhaar', 'aak', 'aalborg', 'aam', 'aanholt', 'aaoifi', 'aaon', 'aap', 'aapd', 'aapl', 'aar', 'aaron', 'aarp', 'aat', 'aau', 'ab', 'aba', 'abacus', 'abacusnext', 'abadi', 'abadon', 'abagnal', 'abanca', 'abandon', 'abasolo', 'abat', 'abatti', 'abax', 'abaxi', 'abaya', 'abb', 'abba', 'abbey', 'abbott', 'abbv', 'abbvi', 'abc', 'abcam', 'abcann', 'abdalla', 'abduct', 'abdul', 'abdullah', 'abdulrahman', 'abe', 'abeja', 'abel', 'abello', 'abenom', 'abeo', 'abeona', 'abercrombi', 'aberdeen', 'abernathi', 'aberr', 'abet', 'abf', 'abha', 'abid', 'abil', 'abilifi', 'abiom', 'abituzumab', 'abl', 'ablat', 'ablaz', 'ablin', 'abloy', 'ablynx', 'abm', 'abn', 'abnorm', 'aboard', 'abod', 'abolish', 'abolit', 'abort', 'abp', 'abpro', 'abr', 'abraaj', 'abraham', 'abram', 'abramovich', 'abraplata', 'abras', 'abrau', 'abraxa', 'abreu', 'abri', 'abroad', 'abrupt', 'absa', 'absenc', 'absent', 'absente', 'absentia']

# %%
# Applying K-means and plotting graph to determine Elbow and optimum number of clusters
from sklearn.cluster import KMeans 
import matplotlib.pyplot as plt 
# %matplotlib inline 

wcss = []
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init= 'k-means++', max_iter= 100, n_init=5, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#Fitting K-means model on vectorized headlines array
from sklearn.cluster import KMeans
#Setting number of clusters to elbow value 
true_k = 3
model = KMeans(n_clusters= true_k, init= 'k-means++', max_iter= 100, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#     n_clusters=3, n_init=1, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
# Outputting top 10 terms for each cluster  
print ("Top terms per cluster:")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(true_k):
    print ("\nCluster %d:" % i, end= " ")
    for ind in order_centroids[i, :10]:
        print (' %s' % terms[ind], end= " ")
    print
# Out:
# Top terms per cluster:
#
# Cluster 0:  brief  q  share  report  announc  new  earn  loss  million  updat
# Cluster 1:  quarter  result  report  financi  announc  fiscal  dividend  corpor  confer  declar
# Cluster 2:  say  trump  china  market  trade  stock  iran  oil  korea  deal

# %%
#Predicting cluster for news text 
print("Prediction")
P_text = tokenize("Finance quarter result")
P_text = ' '.join(P_text)
Y = vectorizer.transform([P_text])
predicted = model.predict(Y)
print(predicted)
# Out:
# Prediction
# [1]

# %%
#Zipping new headlines list with kmeans labels and sorting on labels
labels = model.labels_
result = zip(prev, labels)
sortedR = sorted(result, key=lambda x: x[1], reverse = False)
sortedR
# Out:
# [(['01/02/2018',
#    'The Wall Street Journal: Peter Thiels VC firm has made a monster bet on bitcoin'],
#   0),
#  (['05/02/2018',
#    'WSJ Wealth Adviser Briefing: Catchy Tickers Gun Purchase Monitoring Diet Vodka'],
#   0),
#  (['05/02/2018', 'Apple proved that it is no longer just an iPhone company'],
#   0),
#  (['05/02/2018',
#    'The dollar is surging into overbought territory warns chart watcher. Heres what it means'],
#   0),
#  (['05/02/2018', 'UPS weighs strategy to deliver bulky goods to boost growth'],
#   0),
#  (['05/02/2018',
#    'Yum Brands to report earnings before the opening bell. Heres what to expect'],
#   0),
#  (['05/02/2018',
#    'Tesla sued by truck start-up which alleges that its design patent was violated'],
#   0),
#  (['05/02/2018',
#    'Everything went backwards at Snap and they are in the penalty box: Fmr. Yahoo COO'],
#   0),
#  (['04/03/2018', 'Snapchat Introduces New Group Video Chat Feature'], 0),
#  (['03/02/2018',
#    'Mueller probing whether Kushners foreign business ties affected White House policies: NBC News'],
#   0),
#  (['03/02/2018',
#    'Amazon scrambles to fix cloud networking issue affecting companies like Atlassian Twilio'],
#   0),
#  (['03/01/2018',
#    'US consumer inflation picks up in January as spending slows'],
#   0),
#  (['03/01/2018',
#    'This $20 million Florida mansion has a closet just for $100000 worth of Air Jordans'],
#   0),
#  (['03/01/2018',
#    'Equifax finds an additional 2.4 million Americans impacted by 2017 breach'],
#   0),
#  (['04/03/2018',
#    'Microsoft calls for dismissal of U.S. Supreme Court privacy fight'],
#   0),
#  (['03/02/2018',
#    'IMF warns that steel aluminum tariffs will likely hurt economies'],
#   0),
#  (['03/02/2018',
#    'You could tank your chance of getting an offer if you bring this up too early in a job interview'],
#   0),
#  (['05/01/2018',
#    'WSJ City PM: Barclays Begins Search for New Chairman EU Concerns Linger Despite Extra Time on Tariffs Ether Faces Scrutiny'],
#   0),
#  (['05/02/2018',
#    'Dr. Oz: We need to make life-saving health tech for everyone not just for rich people'],
#   0),
#  (['05/02/2018', 'Apple Has Already Built Its Next Big Business'], 0),
#  (['05/02/2018', "Down In Front! (Thursday May 3)'"], 0),
#  (['03/01/2018',
#    'Heres what you need to earn to buy a home in these big cities'],
#   0),
#  (['02/01/2018',
#    "Vloggers created a $205 'Big Mac with Wagyu beef and Veuve Clicquotheres everything in it"],
#   0),
#  (['03/05/2018',
#    'Dubai International Financial Centre sees higher growth in new companies - Reuters'],
#   0),
#  (['03/05/2018',
#    'Bill Cosby will fight bid to call more accusers at sexual abuse retrial'],
#   0),
#  (['03/05/2018',
#    'Egypt TV host released on bail after being held for defaming police: sources'],
#   0),
#  (['03/06/2018',
#    'Billy McFarland organizer of disastrous Fyre Festival pleads guilty to misleading investors'],
#   0),
#  (['03/06/2018',
#    'Heres another reason to think twice before using your debit card'],
#   0),
#  (['02/01/2018',
#    'Viacom board said to be in talks to set up committee to explore CBS deal'],
#   0),
#  (['02/01/2018',
#    'Elon Musks Boring Company sells all of its flamethrowers in less than a week'],
#   0),
#  (['01/01/2018', 'Bitcoin Is Already Having a Bad Year'], 0),
#  (['01/01/2018',
#    'American Girl Debuts New Doll an Aspiring Astronaut Named Luciana'],
#   0),
#  (['05/03/2018', '4 reasons crypto still isnt mainstream'], 0),
#  (['05/03/2018', 'The surprising story behind Trader Joes 19 cent bananas'],
#   0),
#  (['05/03/2018',
#    'Born in a dishwasher drawer an Italian spin on currency mining'],
#   0),
#  (['05/02/2018', 'Euro zone economy slows as expected in first quarter'], 0),
#  (['02/02/2018', 'Where the jobs are: Houstons police shortage'], 0),
#  (['02/02/2018', 'Nvidias massive run reminds me of the tech bubble'], 0),
#  (['04/02/2018', 'Energy sector in correction territory'], 0),
#  (['03/02/2018',
#    'No-frills micro hospitals with as few as 8 rooms emerge as a new way to cut health-care costs'],
#   0),
#  (['03/02/2018',
#    'Why Verizons CEO is banking on diversityand asking men to help'],
#   0),
#  (['05/02/2018',
#    'Commodities tomorrow: Crude up in spite of bearish inventory report'],
#   0),
#  (['05/03/2018',
#    'Retail leads planned job cuts in 2018 while technology bounces back'],
#   0),
#  (['03/01/2018',
#    '15000 internet-connected devices could be hacked to mine $1000 of cryptocurrency in 4 days'],
#   0),
#  (['01/03/2018',
#    'U.S. factory activity accelerates; construction spending at record high'],
#   0),
#  (['02/02/2018',
#    'US consumer sentiment falls less than expected remaining near all-time highs'],
#   0),
#  (['05/01/2018',
#    'Deutsche Telekom Expects Debt Repayment If T-Mobile Buys Sprint - CFO Journal. - WSJ'],
#   0),
#  (['05/01/2018',
#    'US extends tariff exemptions for European Union and other allies'],
#   0),
#  (['05/02/2018', 'Podcast: Blockchain as Lie Detector'], 0),
#  (['05/02/2018',
#    'BRIEF-Thomson Reuters Provides Information Related To Future Financial Reporting Outlook - Reuters'],
#   0),
#  (['02/01/2018', 'Apple earnings are coming after the bell'], 0),
#  (['01/03/2018', 'Southwest Airlines to Boeing: Well take the large'], 0),
#  (['01/03/2018',
#    'UPDATE 1-Petrobras to pay $2.95 bln to settle U.S. class action over corruption'],
#   0),
#  (['01/03/2018',
#    'Tesla delivers 1550 Model 3 sedans and 29870 total vehicles in fourth quarter'],
#   0),
#  (['01/03/2018',
#    'UPDATE 2-Brazils Petrobras settles U.S. corruption class action for $2.95 bln'],
#   0),
#  (['01/03/2018', 'Ubers Financials: An Inside Look - Wall Street Journal'], 0),
#  (['01/02/2018',
#    'US appeals court revives proposed debt collection class action - Reuters'],
#   0),
#  (['01/31/2018',
#    'Humor Rivalry and Billions of Dollars: A Brief History of Super Bowl Ads'],
#   0),
#  (['02/02/2018', 'Heres where the jobs are  in one chart'], 0),
#  (['02/01/2018',
#    'UPDATE 1-Swiss bank PKB broke money-laundering rules in Brazilian cases - FINMA'],
#   0),
#  (['02/02/2018',
#    'Earnings are up and revenue growth is back but rate hikes could derail momentum'],
#   0),
#  (['02/01/2018',
#    'Cramer tackles Facebook Apple Amazon and Alphabet earnings as tech giants report'],
#   0),
#  (['02/28/2018', 'Senators will try to pull U.S. from Yemen war'], 0),
#  (['03/01/2018',
#    'Elon Musks brother Kimbal: This was the \'best decision of my life"'],
#   0),
#  (['04/01/2018', 'U.S. safety agency criticizes Tesla crash data release'], 0),
#  (['04/30/2018', 'Cramer Remix: The world has turned on this sector'], 0),
#  (['05/01/2018',
#    'Watch: Pelicans crash a California graduation and 1 lands on the red carpet'],
#   0),
#  (['02/05/2018',
#    "US forces begin reducing numbers in Iraq after Iraq declares 'victory over Islamic State"],
#   0),
#  (['02/05/2018', 'No signs of an imminent recession: Strategist'], 0),
#  (['01/01/2018', 'Copper prices set to continue gains in 2018'], 0),
#  (['05/02/2018',
#    'At least five dead in crash of Puerto Rican Air National Guard cargo plane'],
#   0),
#  (['01/02/2018', 'Data SheetAn Apple Conspiracy Theory Blooms'], 0),
#  (['05/02/2018',
#    'The analysts were wrong: The iPhone X is still the most popular iPhone'],
#   0),
#  (['03/01/2018', 'Gap shares soar on earnings beat'], 0),
#  (['02/28/2018', 'Medtronic takes another step toward value-based care'], 0),
#  (['01/02/2018', "Will central banks undershoot on inflation in 2018?'"], 0),
#  (['01/02/2018',
#    'Cramers S&P 500 and Dow charts indicate a strong start to 2018'],
#   0),
#  (['01/03/2018',
#    'Vice Suspends Two Brotopia Iceland Equal Pay: Broadsheet for January 3rd'],
#   0),
#  (['02/02/2018',
#    'Here are the 10 most important stories for investors Friday morning'],
#   0),
#  (['02/01/2018',
#    'This new group is angry about high drug prices  and plan to make 2018 candidates pay attention'],
#   0),
#  (['02/01/2018',
#    'In the midst of the #MeToo movement office romance hits a 10-year low'],
#   0),
#  (['02/01/2018',
#    'Release the GOP Russia memo. We deserve government transparency'],
#   0),
#  (['01/03/2018',
#    'The off-price sector long retails favorite could be losing steam in 2018'],
#   0),
#  (['02/01/2018',
#    'UPenn to remove Steve Wynns name from outdoor plaza revoke his honorary degree'],
#   0),
#  (['02/01/2018',
#    'GOP memo about the Russia probe is likely to be released soon. Heres what to watch for'],
#   0),
#  (['05/02/2018',
#    'Climate Change May Deeply Wound Long-Term U.S. Growth Richmond Fed Paper Finds'],
#   0),
#  (['05/02/2018', 'User growth sinks and hits Snap shares'], 0),
#  (['05/01/2018',
#    'Food photos and music: These top millennial stocks could see huge moves on earnings this week'],
#   0),
#  (['05/01/2018',
#    'Saving in an IRA has its rewards  and risks  for these high-income earners'],
#   0),
#  (['05/01/2018',
#    'Apple shares to rally more than 30% the next 12 months because of its high margins valuable brand: Analyst'],
#   0),
#  (['05/02/2018', 'Macys acquires New York concept shop Story'], 0),
#  (['05/02/2018',
#    'Australia: UPDATE 2-Australias CBA ordered to boost capital until governance failings fixed'],
#   0),
#  (['05/02/2018',
#    "Cramer: Snaps earnings call was like a 'Saturday Night Live parody"],
#   0),
#  (['05/01/2018', 'Verizons Oath signs distribution deal with Samsung'], 0),
#  (['05/02/2018', 'Brazil drought hits second-corn dry spell persists'], 0),
#  (['01/02/2018', "Orrin Hatch Retiring...'"], 0),
#  (['03/01/2018', 'Visa just made a huge commitment on renewable electricity'],
#   0),
#  (['05/02/2018', 'Eurozone Economy Stumbles in First Quarter'], 0),
#  (['05/02/2018',
#    'Parsing the Fed: How the May Statement Changed From March - Real Time Economics - WSJ'],
#   0),
#  (['01/02/2018',
#    'Asian factories end robust 2017 on mixed note; central banks seen hiking slowly'],
#   0),
#  (['05/02/2018',
#    'Oprah gave ex-NFL star Ricky Williams the best advice he ever got  and anyone can follow it'],
#   0),
#  (['05/02/2018',
#    'Sellers are increasingly stripping out luxury homes instead of tricking them out'],
#   0),
#  (['04/03/2018',
#    'Woman executive of South Koreas Hyundai Motor resigns amid #MeToo wave: Yonhap'],
#   0),
#  (['01/02/2018', 'The 10 biggest charitable gifts of 2017'], 0),
#  (['05/02/2018',
#    'These retirees may see their Medicare costs rise by more than 200 percent'],
#   0),
#  (['03/01/2018',
#    'Watch Jaguar unveil its first all-electric vehicle designed to take on Tesla Model X'],
#   0),
#  (['02/01/2018', 'Germany opens anti-trust probe into online advertising'], 0),
#  (['01/03/2018',
#    'Here are the 10 most important stories for investors Wednesday morning'],
#   0),
#  (['01/02/2018', 'U.S. threatens to withhold aid cash to Palestinians'], 0),
#  (['03/02/2018',
#    'The timing of the proposed US steel tariffs is out of synch'],
#   0),
#  (['04/03/2018',
#    'Mueller Was Authorized to Investigate Paul Manaforts Work for Ukraine'],
#   0),
#  (['04/03/2018',
#    'Bitcoin just had its worst start to the year ever. Heres why this quarter could be better'],
#   0),
#  (['03/01/2018', "General Motors February sales down 6.9% vs. 3.0% est.'"], 0),
#  (['05/01/2018',
#    'Cramer reflects on Apple earnings after speaking with CEO Tim Cook'],
#   0),
#  (['02/02/2018',
#    '1 million US jobs will vanish by 2026. Heres how to prepare workers for an automated future'],
#   0),
#  (['02/01/2018',
#    'Justice Department requests more information on CVS-Aetna merger'],
#   0),
#  (['02/02/2018',
#    'REFILE-UPDATE 2-Swiss bank PKB broke money-laundering rules in Brazilian cases - FINMA'],
#   0),
#  (['02/02/2018',
#    'As retailers herald tax savings theyre still closing stores and laying off workers'],
#   0),
#  (['01/03/2018',
#    'Mobileye deal boosts Israeli high-tech exits to $23 billion in 2017'],
#   0),
#  (['01/03/2018', 'Nigerias Buhari re-election movement gathers pace for 2019'],
#   0),
#  (['01/02/2018',
#    'GRAINS-U.S. wheat rallies as temperatures fall; corn soy firm'],
#   0),
#  (['01/02/2018', 'FDA issues recall on Johnson & Johnson heart device'], 0),
#  (['02/01/2018',
#    'Do Standing Desks Really Help You Lose Weight? The Verdict Is In'],
#   0),
#  (['02/01/2018',
#    'What to expect when Alphabet FANGs true blue chip reports earnings'],
#   0),
#  (['04/02/2018',
#    'JPMorgans top blockchain executive Amber Baldet to leave for own startup'],
#   0),
#  (['01/31/2018', 'Brazils pre-salt reserves provide half of oil production'],
#   0),
#  (['02/02/2018',
#    'Former FBI director Comey defends the FBI slams \'weasels and liars"'],
#   0),
#  (['02/02/2018',
#    'Janet Yellen exits the Fed today amid both heavy praise and bitter criticism'],
#   0),
#  (['02/02/2018', 'Mortgage rates jump even higher after positive jobs report'],
#   0),
#  (['02/02/2018',
#    'Deutsche Bank posts third consecutive annual loss in 2017 - Reuters'],
#   0),
#  (['03/01/2018', 'US weekly jobless claims drop to lowest level since 1969'],
#   0),
#  (['05/02/2018',
#    'Stocks to Watch: Apple T-Mobile Mastercard Snap CVS Mondelez Xerox Gilead Clorox Allstate Coors - MoneyBeat - WSJ'],
#   0),
#  (['05/02/2018', 'Unhappy Soccer Fans No Good for Gambling Group'], 0),
#  (['05/01/2018',
#    'Facebook privacy scandal wont slow Main Street retailers social ad spend'],
#   0),
#  (['05/01/2018',
#    "Facebook smart speakers may come to international markets first will include 'M smart assistant"],
#   0),
#  (['05/01/2018',
#    'Disney is launching a digital food channel called Disney Eats'],
#   0),
#  (['04/30/2018',
#    'US wants 4-year phase-in for higher NAFTA auto content thresholds'],
#   0),
#  (['01/03/2018',
#    'Amazon Echo vs. Google Home: How Competing Price Cuts Dominated the Holiday Season'],
#   0),
#  (['05/01/2018',
#    'The states with the highest and lowest credit card balances'],
#   0),
#  (['03/01/2018', 'Women looking for Oscar love in best picture cliffhanger'],
#   0),
#  (['03/01/2018',
#    "A '90s-style personal digital assistant thats a smartphone with a keyboard has launched in case you miss BlackBerry"],
#   0),
#  (['03/02/2018', 'A photographers journey out of Venezuela'], 0),
#  (['03/02/2018', 'Special report: A journey on a caravan of misery'], 0),
#  (['04/03/2018', 'NY Fed names Williams to top post amid political backlash'],
#   0),
#  (['04/03/2018',
#    'Villanova takes NCAA mens basketball title 79-62 over Michigan'],
#   0),
#  (['04/01/2018', 'Palestinian Protests Pose Fresh Hurdles for Israel'], 0),
#  (['04/03/2018',
#    'Both Silicon Valley and Wall Street are taking notes on Spotifys unconventional debut'],
#   0),
#  (['02/01/2018',
#    'CBS and Viacom boards form exploratory committees and hire bankers to mull a deal'],
#   0),
#  (['05/02/2018', 'The best credit card for international travel'], 0),
#  (['02/04/2018', 'How to Watch the 2018 Super Bowl Online for Free'], 0),
#  (['04/01/2018', "Insults fly after Gaza deaths...'"], 0),
#  (['01/02/2018',
#    'Cramers lightning round: Buy Becton Dickinsons stock hand over fist'],
#   0),
#  (['01/02/2018', 'After-hours buzz: MGI TTPH & more'], 0),
#  (['01/03/2018',
#    'German hate speech law tested as Twitter blocks satire account'],
#   0),
#  (['01/03/2018',
#    'Spark prices the first US gene therapy drug at $850000  which is actually less than expected'],
#   0),
#  (['05/02/2018',
#    'Irish High Court refuses Facebook bid to delay privacy case referral'],
#   0),
#  (['05/02/2018',
#    "United Will Soon Allow Some Cats and Dogs Back Into Its Cargo Holds. Here Are the New Rules.'"],
#   0),
#  (['04/02/2018', 'You Can Get Free Little Caesars Pizza Today'], 0),
#  (['04/02/2018', 'Intel shares tumble on report of Apple chip switch'], 0),
#  (['03/01/2018', "Ford February US sales drops 6.9%'"], 0),
#  (['04/02/2018',
#    'Elon Musk Is Trying to Laugh His Way Out of Teslas Worst Month in 7 Years'],
#   0),
#  (['05/02/2018',
#    '4 life goals Americans are putting off because they cant pay their debt'],
#   0),
#  (['05/02/2018',
#    'Clean energy sector swings Republican with U.S. campaign donations'],
#   0),
#  (['01/02/2018',
#    'Times Up Hoda Kotb leads Today Gretchen Carlson: Broadsheet for January 2nd'],
#   0),
#  (['01/02/2018', 'How to buy ripple one of the hottest bitcoin competitors'],
#   0),
#  (['01/02/2018',
#    'Heres why cryptocurrencies could soon be facing a big crackdown'],
#   0),
#  (['05/02/2018',
#    'Google leadership coach: The best way to attract high-performing employees doesnt cost a dime'],
#   0),
#  (['05/02/2018',
#    'Stocks making the biggest moves premarket: CVS CLX EL GRMN YUM ADP & more'],
#   0),
#  (['04/03/2018',
#    'Why Hershey Is Investing $500 Million in Its Chocolate Kisses'],
#   0),
#  (['01/01/2018',
#    'Caterpillars $2 billion tax fight with the IRS could change how US companies do business'],
#   0),
#  (['05/03/2018',
#    'KKR shares jumps 10% after private equity firm announces structuring change'],
#   0),
#  (['02/02/2018', '6 NFL stars who live like theyre broke'], 0),
#  (['01/02/2018',
#    'Tony Robbins: This is the difference between people who stick to resolutions and those who dont'],
#   0),
#  (['04/03/2018',
#    'SEC Charges $32 Million DJ Khaled-Backed Centra ICO With Fraud'],
#   0),
#  (['04/03/2018',
#    "Britain wants 'proportionate response to Russia after spy poisoning"],
#   0),
#  (['01/01/2018',
#    'Jordan royal palace denies rumors about dismissal of princes'],
#   0),
#  (['04/03/2018',
#    'Fox News Defends Laura Ingraham Over David Hogg Denouncing Advertising Boycott as Intimidation Efforts'],
#   0),
#  (['05/02/2018', 'Super-rich paying extra for stripped down real estate'], 0),
#  (['05/03/2018',
#    'WSJ Wealth Adviser Briefing: Bitcoin Portfolio Tweaks Big Gulps'],
#   0),
#  (['05/03/2018',
#    '5 Things to Watch in the April Jobs Report - Real Time Economics - WSJ'],
#   0),
#  (['03/01/2018',
#    'Mueller builds a case against Russians who leaked Democrat emails during the 2016 election'],
#   0),
#  (['03/02/2018', 'There are better methods to solve steel overcapacity'], 0),
#  (['03/02/2018',
#    'Arthur Laffer: Puerto \'shortsighted fiscal plan totally \'misses the mark"'],
#   0),
#  (['05/02/2018',
#    'An old Wall Street money manager with $500 billion is moving to Nashville from Manhattan to save money'],
#   0),
#  (['05/02/2018',
#    'CFO Moves: MetLife Honeywell International Lloyds of London'],
#   0),
#  (['05/01/2018',
#    'How one trader is playing the Nasdaq ahead of Apple earnings'],
#   0),
#  (['04/01/2018', 'Everything That Is Open (and Closed) on Easter Sunday 2018'],
#   0),
#  (['05/01/2018', 'Apple sold 52.2 million iPhones during the quarter'], 0),
#  (['04/30/2018',
#    'Twitter doubles down on original shows with NBCUniversal Disney Viacom and more'],
#   0),
#  (['04/30/2018',
#    'Watch CNBCs full interview with Freeport LNG CEO Michael Smith'],
#   0),
#  (['04/02/2018',
#    'Kevin Carwile Laura Ingraham Justice Department: Broadsheet April 2'],
#   0),
#  (['02/03/2018', 'Apple Sets Records With Its Best iPhone Ever'], 0),
#  (['03/01/2018',
#    'For sale: Boone Pickens $250 million ranch. Take a look inside."'],
#   0),
#  (['01/02/2018',
#    'This couple bought 40 acres for $9000 years agonow their pot farm is worth millions'],
#   0),
#  (['01/03/2018',
#    '2 Democrats to be sworn in as senators narrowing the GOPs majority in Congress'],
#   0),
#  (['02/28/2018', 'Mylan earnings fall with EpiPen sales weak generic prices'],
#   0),
#  (['05/02/2018',
#    'SpongeBob and Frozen Are Among the Highest-Grossing 2018 Tony Nominees'],
#   0),
#  (['01/03/2018', 'Macys is about to close more stores'], 0),
#  (['01/03/2018', 'Heres why Amazon may not buy Target'], 0),
#  (['01/03/2018',
#    'Ackmans Pershing Square Valeant to appear in court to discuss an insider trading lawsuit settlement'],
#   0),
#  (['01/03/2018',
#    'Intel CEO: We believe we have the right fixes for security exploit'],
#   0),
#  (['02/01/2018',
#    'I Am a Good Guy Who Made a Bad Decision: Logan Paul Apologizes for Suicide Video on Good Morning America'],
#   0),
#  (['04/03/2018',
#    'A key rate for banks has jumped to the highest since the financial crisis but Goldman Sachs isnt worried'],
#   0),
#  (['04/02/2018',
#    'Amazon executives have reportedly started their headquarters search visits. Heres what theyre asking about'],
#   0),
#  (['04/02/2018', 'A look at the uncertainty surrounding US soybean exports'],
#   0),
#  (['03/01/2018',
#    "There will be some 'unintended consequences to proposed US steel aluminum tariffs"],
#   0),
#  (['02/02/2018',
#    'Zuckerberg doesnt want Facebook to edit news because its users can do it better'],
#   0),
#  (['05/01/2018',
#    'Tyson Foods nearly doubles investor money in three years: CEO'],
#   0),
#  (['01/03/2018',
#    'Four Kosovo MPs get suspended jail terms for tear gas protest'],
#   0),
#  (['04/30/2018',
#    'U.S. jury convicts former Autonomy executive of fraud over HP deal'],
#   0),
#  (['05/01/2018', 'Sugar Low: Commodity Plummets on Surplus'], 0),
#  (['03/31/2018', "Pope baptizes Italy 'migrant hero at Easter Eve service"],
#   0),
#  (['02/02/2018',
#    'Fired FBI director James Comey rips \'dishonest and misleading GOP Russia memo  \'Thats it?\'"'],
#   0),
#  (['02/01/2018',
#    'The average selling price of an iPhone is $100 higher than it was a year ago'],
#   0),
#  (['02/02/2018',
#    "Amazon CFO: advertising was a 'key contributor to revenue growth in Q4"],
#   0),
#  (['02/01/2018', 'GoPro misses revenue forecast for holiday quarter'], 0),
#  (['03/01/2018',
#    'CORRECTED-RPT-FOCUS-Bunges coveted Argentina plants lure ADM takeover approach'],
#   0),
#  (['03/01/2018', 'Brazils economy ended slide in 2017; grew 1 percent'], 0),
#  (['03/02/2018', "Bosch hires 'internet of things expert from SAP"], 0),
#  (['02/04/2018', 'The Best Super Bowl Deals on Pizza Wings and More'], 0),
#  (['02/05/2018',
#    'Amtrak blames freight train operator CSX for its deadly South Carolina crash'],
#   0),
#  (['04/03/2018', 'How to decipher that college financial aid offer'], 0),
#  (['02/05/2018', 'Stifel CEO on sell-off: Everybody needs to relax'], 0),
#  (['02/05/2018',
#    'Samsungs Lee Jae-yong Has Been Released From Prison After a Successful Appeal'],
#   0),
#  (['01/03/2018',
#    'Watch: White House press secretary Sarah Sanders briefs reporters'],
#   0),
#  (['03/01/2018', 'The bull case for Nordstrom ahead of earnings'], 0),
#  (['03/01/2018',
#    'Beware Qualcomm: Broadcom is used to winning battles with hostility as Amazon knows'],
#   0),
#  (['03/02/2018',
#    'People keep mistaking the National Restaurant Association for the NRA'],
#   0),
#  (['02/01/2018',
#    'MItt Romney will make announcement on Utah Senate race on Feb. 15'],
#   0),
#  (['02/01/2018', '4 things Bill Belichick asks the Patriots to do every day'],
#   0),
#  (['02/01/2018',
#    'Google CEO: A.I. is more important than fire or electricity'],
#   0),
#  (['02/01/2018',
#    'BRIEF-Google Says To Build Additional Data Center In Belgium - Blog'],
#   0),
#  (['03/02/2018', 'Billionaire CEO Steve Schwarzman: Dont start a business'],
#   0),
#  (['02/01/2018', 'Lowes confirms plans to pay up to $1000 bonuses'], 0),
#  (['02/02/2018',
#    'Inside the Shakeup at Airbnb: The Startup Loses a CFO Gains a COO - Fortune'],
#   0),
#  (['02/02/2018', 'Pepsi has been training for the Super Bowl for six months'],
#   0),
#  (['02/02/2018',
#    'Consumers shopping sprees are giving new life to the Boeing 747'],
#   0),
#  (['03/02/2018',
#    "Bank of Englands Carney calls for more regulation around the 'speculative mania of cryptocurrencies"],
#   0),
#  (['03/02/2018',
#    'How DJ Khaled went from broke and in jail to making $24 million working with Jay-Z'],
#   0),
#  (['03/01/2018',
#    'Best Buy same-store sales surge during the key holiday quarter; shares leap'],
#   0),
#  (['02/02/2018',
#    'Walmart Sams Club closures spell gains for Costco: JP Morgan'],
#   0),
#  (['04/30/2018', 'SEC Wants Boards Views on Contested Shareholder Proposals'],
#   0),
#  (['05/01/2018',
#    'Watch Steve Jobs defend his commitment to Apple on CNBC in 1997'],
#   0),
#  (['05/01/2018',
#    'Marathon-Andeavor merger checks the boxes where it counts: Texas Mexico and the high seas'],
#   0),
#  (['02/02/2018',
#    "Minneapolis Feds Kashkari: Strong January jobs data show 'one of the first signs of long-awaited wage growth"],
#   0),
#  (['04/02/2018', 'Term Sheet  Monday April 3'], 0),
#  (['02/02/2018',
#    'UPDATE 3-Exxon profit misses Street on refining chemical weakness - Reuters'],
#   0),
#  (['01/03/2018',
#    'UPDATE 1-Vale is negotiating BHP exit from Samarco venture -sourceGG'],
#   0),
#  (['02/01/2018',
#    'Fresh from peacock incident United sets stricter standards for emotional support animals'],
#   0),
#  (['02/02/2018',
#    'NFL concussions strategy for 2018 Super Bowl includes a roster change'],
#   0),
#  (['02/02/2018',
#    'Cramer to Google-parent Alphabet: I want the Super Bowl of earnings'],
#   0),
#  (['02/02/2018', 'Apple vows to cut its $163 billion in net cash to \'zero"'],
#   0),
#  (['04/01/2018',
#    'Cloudflare Announces a Faster More Private Internet Directory'],
#   0),
#  (['05/01/2018', 'How I Empower the Introverts on My Staff'], 0),
#  (['03/02/2018',
#    'UPDATE 1-Euro zone bonds sailing into weekend of key risk events - Reuters'],
#   0),
#  (['03/02/2018',
#    'The dangerous new dance as corporations balance business and social risk'],
#   0),
#  (['01/02/2018', 'US energy infrastructure firms show good value'], 0),
#  (['02/01/2018',
#    'An Animated Super Mario Bros. Movie Is Coming and the Minions Studio Will Make It'],
#   0),
#  (['02/01/2018',
#    'Pharma trade group urges appeals court to save Allergans Restasis patents - Reuters'],
#   0),
#  (['02/01/2018',
#    'Italy\\\'s Enel: "no interest in powering cryptocurrency miners'],
#   0),
#  (['02/01/2018',
#    'Brenda Fitzgerald Larry Nassar Walmart: Broadsheet for Feb. 1'],
#   0),
#  (['01/03/2018', "Italys Northern League pledges to put right 'error of euro"],
#   0),
#  (['01/03/2018', 'Petrobras agrees to pay $2.95B to settle case in the US'],
#   0),
#  (['01/03/2018',
#    'With tax law not positive for housing top analyst finds value away from homebuilders'],
#   0),
#  (['04/03/2018',
#    'Billionaire Virgin Hyperloop One Director Arrested on Fraud and Embezzlement Charges'],
#   0),
#  (['01/03/2018', 'Spotify makes confidential filing for U.S. IPO: source'], 0),
#  (['01/03/2018',
#    'Mobileye deal boosts Israeli high-tech exits to $23 billion in 2017'],
#   0),
#  (['02/01/2018',
#    'Cuba hands note of protest to U.S. over internet task force'],
#   0),
#  (['02/01/2018', 'GoPro set to report after the close'], 0),
#  (['02/01/2018',
#    'Cigna CEO sees Amazon-led employee health initiative as an \'opportunity"'],
#   0),
#  (['02/01/2018',
#    'Maldives top court orders retrial of ex-president opposition leaders'],
#   0),
#  (['02/02/2018',
#    'Alphabet downgraded on rising competition from Amazon in ads cloud computing'],
#   0),
#  (['02/01/2018',
#    'Mastercard profit tops Street on holiday shopping rush; shares hit record'],
#   0),
#  (['05/02/2018', 'Hulu surpasses 20 million US subscribers'], 0),
#  (['05/02/2018', 'What this WWE billionaire learned from bankruptcy'], 0),
#  (['02/01/2018',
#    'GOP lawmakers put their medical skills to work after a deadly train crash'],
#   0),
#  (['01/05/2018',
#    'Rising commodity prices due to investment increase: Commerzbank'],
#   0),
#  (['01/05/2018',
#    'Retail industry was reason behind weak jobs report but construction jobs still booming'],
#   0),
#  (['01/04/2018',
#    'Half-ton butter sculpture unveiled at Pennsylvania Farm Show'],
#   0),
#  (['05/02/2018',
#    'Sprint names Michel Combes as CEO and Marcelo Claure as executive chairman'],
#   0),
#  (['01/03/2018',
#    'Richard Bransons simple trick to come up with an idea for a successful business'],
#   0),
#  (['03/02/2018', 'UPDATE 2-Microchip to buy Microsemi for about $8.35 bln'],
#   0),
#  (['01/03/2018',
#    'UPDATE 1-Petrobras to pay $2.95 bln to settle U.S. class action over corruption'],
#   0),
#  (['02/02/2018',
#    'Cramers guide to the sell-off: \'Its not the end of the world"'],
#   0),
#  (['04/01/2018', 'Spielbergs Ready Player One Debuts at No. 1 at Box Office'],
#   0),
#  (['02/01/2018',
#    'Chipotle downgraded to sell by UBS citing worse brand perception than when food safety crisis began'],
#   0),
#  (['02/01/2018',
#    'Stocks making the biggest moves premarket: DWDP BABA BX UPS FB MSFT QCOM & more'],
#   0),
#  (['02/01/2018', 'Heres why one bitcoin bear is turning bullish'], 0),
#  (['02/01/2018', 'Lowes bonuses: Heres what employees will receive'], 0),
#  (['05/02/2018',
#    'The Morning Ledger: U.S. Companies Squeezed by Rising Commodity Prices'],
#   0),
#  (['05/02/2018', 'Amazon gallops into the Kentucky Derby'], 0),
#  (['05/02/2018', 'Cramer: Snaps conference call was like SNL parody'], 0),
#  (['05/02/2018', 'Fed holds rates steady but points to higher inflation'], 0),
#  (['05/02/2018',
#    'A Tight Rein on Finances Helps Bosch Keep Up with Rivals - CFO Journal. - WSJ'],
#   0),
#  (['05/02/2018',
#    "Four of the worlds largest automakers want to bring the 'blockchain to your car"],
#   0),
#  (['04/30/2018', 'Cloud Revenues See Sharper Gains - CIO Journal. - WSJ'], 0),
#  (['02/01/2018',
#    "'Disrgraced : Pelosi demands removal of Rep. Nunes as House Intelligence chair over Russian probe"],
#   0),
#  (['01/31/2018',
#    'Ebay posts loss for holiday quarter as it books $3.1 billion tax charge'],
#   0),
#  (['03/01/2018', 'Kohls earnings beat on the top and bottom lines'], 0),
#  (['03/01/2018', "MAG: Nuns exploited for cheap Church labor...'"], 0),
#  (['03/01/2018',
#    'Huawei distances itself from CEO comments after he goes off-script and rages over US snub'],
#   0),
#  (['03/01/2018',
#    'UK rules out holding second part of inquiry into press ethics'],
#   0),
#  (['03/01/2018',
#    'Best Buy posts higher comparable sales during key holiday quarter'],
#   0),
#  (['05/02/2018', 'Think Youre Too Old to Found a Startup? Think Again'], 0),
#  (['05/03/2018',
#    'After a year of Macron start-up hum grows at Pariss Station F'],
#   0),
#  (['05/03/2018',
#    'Activision Blizzard reports 15.7 percent rise in adjusted revenue'],
#   0),
#  (['05/03/2018',
#    'Here are highlights of Elon Musks strange Tesla earnings call: \'Theyre killing me"'],
#   0),
#  (['01/03/2018',
#    'If you invested $1000 in Disney 10 years ago heres what youd have now'],
#   0),
#  (['01/03/2018',
#    'Big Tech Sends Nasdaq to New Record High: CEO Daily for January 3 2018'],
#   0),
#  (['05/02/2018',
#    'Square drops 6 percent after issuing a disappointing forecast'],
#   0),
#  (['01/04/2018', 'See Harrowing Footage of Icy Floods Along East Coast'], 0),
#  (['03/02/2018', 'Why companies with more female executives make more money'],
#   0),
#  (['04/03/2018', 'raceAhead: Eliminating Bias Through Checklists'], 0),
#  (['01/06/2018',
#    'Forget Face ID. The Future of Secure Authentication Is Your Voice'],
#   0),
#  (['01/03/2018',
#    'Brazilian agency requires Apple to inform consumers on batteries'],
#   0),
#  (['01/04/2018',
#    'This Company Is Set to Become a Driving Force Behind Fully Autonomous Vehicles'],
#   0),
#  (['01/04/2018',
#    "Cramer: AMDs CEO will 'take advantage of Intels security flaw fallout"],
#   0),
#  (['01/04/2018', 'Tesla guidance disappoints'], 0),
#  (['01/05/2018',
#    'Justice Dept launches new Clinton Foundation probe: The Hill'],
#   0),
#  (['03/01/2018',
#    'HUD chief Ben Carson moves to cancel order for $31561 executive dining room set'],
#   0),
#  (['01/05/2018',
#    'The countrys most innovative bar is serving a $27 cocktail packaged in a pillow of bagel air'],
#   0),
#  (['01/05/2018', 'Spotify reaches 70 million subscribers'], 0),
#  (['01/05/2018',
#    'Winter storm forces worlds largest passenger jet to divert to small New York airport'],
#   0),
#  (['02/01/2018', 'Apples cash pile hits $285.1 billion a record'], 0),
#  (['01/05/2018',
#    'Heres what to expect at CES this year: Smart homes robots TVs and more'],
#   0),
#  (['01/06/2018',
#    'E. coli outbreak linked to romaine lettuce frustrates produce industry'],
#   0),
#  (['01/06/2018',
#    'Google Microsoft and Amazons Trade Group Joining Net Neutrality Court Challenge'],
#   0),
#  (['01/04/2018',
#    'BRIEF-Google Says Its Project Zero Security Team Last Year Discovered Vulnerability Affecting Modern Microprocessors - Blog'],
#   0),
#  (['04/04/2018',
#    'In Africa scant data protection leaves internet users exposed'],
#   0),
#  (['03/01/2018',
#    "REFILE-UPDATE 1-Four Fed rate hikes this year would be 'gradual -Dudley"],
#   0),
#  (['01/02/2018', 'Amazon could buy Target in 2018: Gene Munster'], 0),
#  (['01/02/2018',
#    'GRAINS-Cold concerns spark U.S. wheat futures rally; corn firm; soy weak'],
#   0),
#  (['01/03/2018',
#    'Are You Eating Sustainable Fish? Blockchain May Provide the Answer'],
#   0),
#  (['01/04/2018', 'Dow Hits 25000: Heres Why It Matters'], 0),
#  (['02/01/2018', 'Heres who is benefiting from Chipotles food safety woes'],
#   0),
#  (['01/05/2018', 'The Final Call: Biotech & more'], 0),
#  (['03/01/2018',
#    'This popular bitcoin strategy is flawed and hurts investors analyst Nick Colas warns'],
#   0),
#  (['01/04/2018', 'How to short bitcoin'], 0),
#  (['01/04/2018',
#    'UPDATE 1-Brazils Santander rural loans rise to $4 bln in 2017'],
#   0),
#  (['01/04/2018',
#    'Brazil 2017 home prices fall for first time in at least a decade'],
#   0),
#  (['01/03/2018',
#    'UPDATE 5-Petrobras to pay $2.95 bln to settle U.S. corruption lawsuit'],
#   0),
#  (['01/03/2018',
#    'Vale is negotiating BHP exit from Samarco venture -sourceGG'],
#   0),
#  (['01/05/2018',
#    'Solid US job growth expected in December with wages seen rising'],
#   0),
#  (['01/05/2018', 'The most popular free apps to keep you healthy in 2018'], 0),
#  (['01/05/2018',
#    'raceAhead: Zuckerbergs New Resolve Genocide Spurred on By Facebook Posts and Toxic Femininity'],
#   0),
#  (['03/01/2018',
#    'Stocks making the biggest moves premarket: BBY KSS HOG BID NWL WMT CRM & more'],
#   0),
#  (['02/02/2018',
#    'Heres what Wall Street analysts thought of Apples earnings report'],
#   0),
#  (['01/05/2018', "DECEMBER JOBS: +148K...'"], 0),
#  (['01/06/2018', 'Last years S&P 500 losers could be prime for speculation'],
#   0),
#  (['01/05/2018',
#    'Cramer: The S&P 500s winners for 2017 could still have room to run this year'],
#   0),
#  (['01/04/2018', 'Art Cashin on Dow 25000'], 0),
#  (['01/04/2018',
#    'Weinstein Company close to selling itself for less than $500 million: Report'],
#   0),
#  (['01/04/2018',
#    'Another tiny digital coin leaps into the top 10 cryptocurrencies'],
#   0),
#  (['01/05/2018',
#    'Self-made millionaire: Once you have some money heres what to do'],
#   0),
#  (['02/02/2018',
#    'This new financial cyberscam costs victims an average $130000 for each attack'],
#   0),
#  (['02/02/2018',
#    '10-year study finds that this is the fastest way to become a CEO'],
#   0),
#  (['02/02/2018', 'Bitcoin is bottoming expect a 70 percent surge: Trader'], 0),
#  (['02/02/2018',
#    'Kenya police arrest opposition member present at Odinga\\\'s "swearing in - Reuters'],
#   0),
#  (['01/05/2018',
#    'Services sector growth slows more than expected in December'],
#   0),
#  (['01/05/2018',
#    'Neiman Marcus names Geoffroy van Raemdonck CEO replacing Karen Katz'],
#   0),
#  (['02/01/2018',
#    'Bitcoin lost 30 percent of its value in January. How to not panic'],
#   0),
#  (['03/01/2018',
#    'Overstock.com drops 10% after revealing SEC investigation into cryptocurrency token sale'],
#   0),
#  (['03/02/2018', 'Sensitivity Training for Madison Avenue'], 0),
#  (['01/04/2018',
#    'Sprint names Michel Combes as president and chief financial officer'],
#   0),
#  (['04/03/2018',
#    'Attorneys general from 11 U.S. states vow to defend auto efficiency standards'],
#   0),
#  (['05/01/2018',
#    'CMS Verma: Its time health care caught up to other industries to aid consumers'],
#   0),
#  (['02/01/2018',
#    'Broadcom said to view Qualcomm earnings as concerning: Sources'],
#   0),
#  (['02/01/2018', 'HBO has more than 5 million online streaming subscribers'],
#   0),
#  (['01/05/2018',
#    'Fundamentals wont be quite as bad for retailers this year: Analyst'],
#   0),
#  (['01/03/2018',
#    'Evercores Stephen Kim on the top homebuilder winners from tax reform'],
#   0),
#  (['01/03/2018', 'Deep freeze across the US'], 0),
#  (['01/05/2018',
#    'Cramers lightning round: Stop talking start buying Raytheon'],
#   0),
#  (['01/05/2018',
#    'Barnes & Noble Shares Plunge 15% On Dismal Holiday Season Sales'],
#   0),
#  (['03/01/2018',
#    'GRAINS-Wheat extends gains into sixth straight session near 7-month high'],
#   0),
#  (['03/02/2018',
#    'SIERENTZ HOLDING LAUNCHES AGRICULTURE PRODUCTS TRADING UNIT SIERENTZ GLOBAL MERCHANTS (SGM), HEADQUARTERED IN SWITZERLAND -CEO'],
#   0),
#  (['03/01/2018',
#    'Jaguars answer to Teslas Model X has a cool Alexa skill and over-the-air updates'],
#   0),
#  (['03/01/2018', "4 Fed rate hikes this year would be 'gradual: Dudley"], 0),
#  (['03/02/2018', "Goldman: 'Good chance this leads to NAFTA withdrawal"], 0),
#  (['01/03/2018', 'GRAINS-K.C. wheat hits six-week top soy firm corn weak'], 0),
#  (['04/30/2018',
#    'This Kevin OLeary backed 28-year-old brings in 6 figures a year selling potatoes through the mail'],
#   0),
#  (['05/02/2018', 'AllianceBernsteins Highway Men To Live Large in Nashville'],
#   0),
#  (['02/01/2018',
#    'Renewables are fully competitive with fossil fuels: rsted CEO'],
#   0),
#  (['02/01/2018',
#    'UPDATE 1-World food prices steady in January cereal output seen at record high - UN FAO'],
#   0),
#  (['02/01/2018', 'The greenback gets whacked'], 0),
#  (['04/01/2018',
#    'U.S. government seeks end to Supreme Court privacy fight with Microsoft'],
#   0),
#  (['04/01/2018',
#    'Hackers Steal Credit Card Information for More Than 5 Million Saks Fifth Avenue Lord & Taylor Shoppers'],
#   0),
#  (['02/02/2018',
#    'Japanese cryptocurrency exchanges in the spotlight after $500 million hack'],
#   0),
#  (['02/02/2018',
#    'A-Rod feels like the sixth \'Gronk brother after investing with Chris Gronkowski on \'Shark Tank"'],
#   0),
#  (['02/02/2018',
#    'Best wage growth since 2009 spurs talk of more Fed rate hikes'],
#   0),
#  (['03/02/2018',
#    "'Hows your 401(k) doing?' Its a good question to ask right now"],
#   0),
#  (['03/01/2018',
#    'Brazil court largely upholds law that some fear hurts Amazon'],
#   0),
#  (['01/04/2018', 'The $10 trillion dollar bull case for cryptocurrecies'], 0),
#  (['04/03/2018',
#    'FDA orders mandatory recall of herbal supplement kratom after a firm refused to do it voluntarily'],
#   0),
#  (['05/03/2018',
#    'Positions on Asian currencies pull back on resurgent dollar: Reuters poll'],
#   0),
#  (['05/03/2018',
#    'Spotify is on pace for its worst day since going public after first earnings report'],
#   0),
#  (['02/02/2018',
#    'Dell confirms talks with VMWare for potentially huge tech deal'],
#   0),
#  (['02/02/2018',
#    'Stocks making the biggest moves premarket: MRK EL AMZN GOOGL AAPL V & more'],
#   0),
#  (['01/04/2018',
#    'Federated: Dow S&P and Nasdaq blow through records and its only getting started'],
#   0),
#  (['04/04/2018', 'Why investing for kids can have huge payoff'], 0),
#  (['04/05/2018',
#    'This map shows where people are suffering financially from student debt'],
#   0),
#  (['04/05/2018', 'For retirees heres how to score a side gig'], 0),
#  (['04/05/2018',
#    'Albertsons to roll out Plated meal kits to hundreds of its stores by end of year'],
#   0),
#  (['04/05/2018', "Why a 'blue wave in the midterm elections wont be enough"],
#   0),
#  (['04/05/2018', 'The wrong investments are sabotaging your retirement plans'],
#   0),
#  (['03/01/2018',
#    "Why leaders should 'never lower the bar' according to one management expert"],
#   0),
#  (['03/01/2018',
#    'Palestinian migrant gets life sentence for supermarket stabbing in Germany'],
#   0),
#  (['02/02/2018',
#    'US adds 200000 jobs in January beating expectations  wages jump'],
#   0),
#  (['02/01/2018', 'Fridays jobs report could carry an inflationary surprise'],
#   0),
#  (['04/06/2018',
#    'Japanese online brokerage to buy Coincheck for 3.6 billion yen'],
#   0),
#  (['04/06/2018',
#    'Malaysian Prime Minister Dissolves Parliament to Make Way for Elections'],
#   0),
#  (['05/02/2018', 'Cambridge Analytica is shutting down'], 0),
#  (['01/06/2018', 'Feeding the beast with a bank earnings kicker'], 0),
#  (['01/04/2018', 'Giant oil companies put exploration on the back burner'], 0),
#  (['03/05/2018',
#    'San Francisco is so expensive that working adults are moving into dorms'],
#   0),
#  (['03/06/2018', 'Energy transition takes decades: Amin Nassar'], 0),
#  (['04/05/2018',
#    'Thousands expected to march in support of South Africas Zuma at court appearance'],
#   0),
#  (['04/05/2018', "Heres how to maximize those retirement 'sweet spot years"],
#   0),
#  (['04/05/2018',
#    'I spent an 11-hour day with a tax pro during tax seasonheres the most surprising thing I learned'],
#   0),
#  (['04/04/2018',
#    'Brazil state fines Anglo American 125.6 mln reais over pipeline leak'],
#   0),
#  (['01/05/2018', 'US factory orders rise for fourth straight month'], 0),
#  (['04/05/2018',
#    'Sears Holding Delta Air hit by customer data breach at tech firm'],
#   0),
#  (['02/01/2018',
#    'World food prices steady in January cereal output seen at record high - UN FAO'],
#   0),
#  (['05/02/2018',
#    'Tesla burns through $6500 every minute. This is the guy trying to rein in the cash crisis'],
#   0),
#  (['03/02/2018',
#    'JD.coms shares slide as investments competition eat into profits'],
#   0),
#  (['04/03/2018',
#    'UPDATE 1-Dubais DAMAC hires banks to set up investor meetings before dollar sukuk - Reuters'],
#   0),
#  (['04/04/2018',
#    'PHOTOS: A Look at Martin Luther Kings Assassination 50 Years Ago Today'],
#   0),
#  (['04/04/2018',
#    'The Wall Street Journal: Activist Elliott Management reveals over $1 billion stake in Hyundai praises clearer reorganization'],
#   0),
#  (['01/05/2018', 'The new tax law is a mixed bag for your company benefits'],
#   0),
#  (['04/30/2018',
#    'Cramer: T-Mobiles John Legere could be the ticket to Sprint merger approval'],
#   0),
#  (['01/03/2018', 'This Is Your Guide to Buying Bitcoin'], 0),
#  (['01/03/2018',
#    'Cold weather burst could lift shares of Dominos Pizza and North Face maker history shows'],
#   0),
#  (['04/08/2018',
#    'Deutsche Bank Is Leaning Toward Christian Sewing as Next CEO'],
#   0),
#  (['04/07/2018',
#    "Facebook suspends Canadian firm AggregateIQ after it may have 'improperly had access to user data"],
#   0),
#  (['04/07/2018', 'House panel investigating Pruitts condo rental'], 0),
#  (['04/07/2018',
#    'Kyrgyz leader fires security boss in sign of ruling party rift'],
#   0),
#  (['04/08/2018', 'Deutsche Banks Sewing to become new group CEO - source'], 0),
#  (['04/09/2018',
#    'Europes Boom Reawakens Debt Worries German Steel Town Fears Tariffs Hungarys Orban in Big Election Win'],
#   0),
#  (['04/09/2018',
#    'Justice Department to allow Bayers acquisition of Monsanto: Dow Jones'],
#   0),
#  (['04/09/2018',
#    "Sen. Kennedy: I hope Mark Zuckerberg doesnt 'pull things out of his orifices when testifying"],
#   0),
#  (['04/09/2018',
#    "Billionaire mall owner: 'Amazon has been great for retail  and heres why"],
#   0),
#  (['05/02/2018', 'Southwest plane with a cracked window diverts to Cleveland'],
#   0),
#  (['05/01/2018',
#    'The Morning Risk Report: U.K. to Target Scottish Firms in Money-Laundering Crackdown'],
#   0),
#  (['05/02/2018',
#    'Spains Basque region militant group ETA announces it has completely dissolved'],
#   0),
#  (['05/02/2018',
#    'Eletrobras reaches initial settlement in US class action case - Reuters'],
#   0),
#  (['05/01/2018',
#    'Hasbro is said to acquire Power Rangers other franchises from Saban'],
#   0),
#  (['05/02/2018', 'Banks See Crude Prices Rising This YearEnergy Journal'], 0),
#  (['05/02/2018', 'Investors Exit U.S. Equity Funds for Third Straight Month'],
#   0),
#  (['05/01/2018', "Key Figures (Wednesday Crossword May 2)'"], 0),
#  (['05/02/2018', "Verizons Oath is 'doubling down on Amazons cloud"], 0),
#  (['05/01/2018',
#    'Amazon plans more Prime perks at Whole Foods and it will change the industry'],
#   0),
#  (['01/04/2018',
#    'U.S. State Department adds three people affiliated with al Qaeda to terrorist list'],
#   0),
#  (['04/08/2018', 'Ohio company recalls more than 7 tons of BBQ beef'], 0),
#  (['05/02/2018',
#    'Heres why the old Sell in May adage is really a no-brainer this year'],
#   0),
#  (['05/02/2018',
#    'Arizona Teachers May Finally End Their Week-Long Statewide Strike'],
#   0),
#  (['05/02/2018', 'Apple beats expectations quelling sales worries'], 0),
#  (['01/04/2018', 'Neurontin prescriptions surge amid opioid crisis'], 0),
#  (['04/04/2018',
#    'PHOTOS: A Look at Martin Luther Kings Assassination 50 Years Ago Today'],
#   0),
#  (['04/04/2018',
#    'Amazon May Start a Bidding War With Walmart Over a Huge International Retailer'],
#   0),
#  (['02/05/2018', 'Broadcom raises offer to buy Qualcomm to $121 billion'], 0),
#  (['05/01/2018', 'The Modern Cell Carrier: How We Got Here'], 0),
#  (['05/02/2018', 'Corporate buybacks on a roll'], 0),
#  (['05/02/2018',
#    'Pro-Brexit lawmakers pressure British PM May over customs plan'],
#   0),
#  (['05/02/2018', "Find out why 'white boxing is real estates hot new trend"],
#   0),
#  (['01/06/2018', 'Pope warns on being misled by the pursuit of money'], 0),
#  (['01/05/2018', 'GoPro cuts 200 to 300 jobs in its aerial products division'],
#   0),
#  (['05/01/2018',
#    'That fortune will be lost if you dont update estate plan to include cryptocurrency assets'],
#   0),
#  (['02/01/2018',
#    'Airbnb is making rents in New York City spike as owners yank units off the market study finds'],
#   0),
#  (['02/01/2018', 'Amazon cloud revenue jumps 45 percent in fourth quarter'],
#   0),
#  (['03/01/2018',
#    'Putin reveals new Russian missile that can \'reach any point in the world"'],
#   0),
#  (['02/01/2018',
#    'Wells Fargo loses a big client after dialing up risk in its target-date retirement funds'],
#   0),
#  (['03/01/2018',
#    'White House preparing for exit of national security advisor HR McMaster: NBC News'],
#   0),
#  (['04/05/2018',
#    'Tariffs would hurt US consumers and companies business group warns'],
#   0),
#  (['04/05/2018',
#    'San Francisco sues Jeff Sessions over repealed civil rights memos'],
#   0),
#  (['04/05/2018',
#    'UPDATE 4-Brazils top court rules that ex-president Lula can be jailed'],
#   0),
#  (['03/02/2018',
#    'Here are the US exports that could get slapped with retaliation by other countries'],
#   0),
#  (['03/02/2018',
#    'Cramers sell-off strategy: This is a great opportunity to buy Amazon'],
#   0),
#  (['02/06/2018', 'The Diseases We Arent CuringAnd Why'], 0),
#  (['05/01/2018',
#    'Small business workers saw their wages grow at the strongest rate in 2 years: Survey'],
#   0),
#  (['05/01/2018',
#    'Buy Roku shares because its the dominant leader in streaming video players: KeyBanc'],
#   0),
#  (['04/03/2018', 'Rules for bulls bears and everyone in between'], 0),
#  (['04/04/2018',
#    'How IBMs game show winning supercomputer is solving problems before they occur'],
#   0),
#  (['04/04/2018',
#    'HSBC has worst gender pay gap among Britains largest companies'],
#   0),
#  (['04/05/2018',
#    "Stifel downgrades Intel on worries its computer-server business is 'peaking' upgrades AMD"],
#   0),
#  (['04/05/2018',
#    'Some Oklahoma teachers find the grass really is greener in Texas'],
#   0),
#  (['05/01/2018',
#    'WSJ Wealth Adviser Briefing: Bank Deposits Debt Hiking Croatia'],
#   0),
#  (['04/05/2018',
#    'Virgin Galactic completes first rocket powered supersonic flight of new spacecraft Unity'],
#   0),
#  (['04/05/2018', 'Heres how to find your lost phone'], 0),
#  (['04/05/2018',
#    'Facebook sent a doctor on a mission to ask hospitals to share patient data'],
#   0),
#  (['01/05/2018',
#    "Party or not? Golden Globes proves test for Hollywood sex scandal...'"],
#   0),
#  (['01/04/2018',
#    'As the U.S. Retreats Europe Moves to Strengthen Ties With Cuba'],
#   0),
#  (['01/04/2018',
#    'Israel proposes ban on trading shares of cryptocurrency companies'],
#   0),
#  (['02/01/2018',
#    'UPDATE 2-Swiss bank PKB broke money-laundering rules in Brazilian cases - FINMA'],
#   0),
#  (['04/06/2018', 'Where the ultra-rich live around the world'], 0),
#  (['04/06/2018',
#    'The most common knee surgery for seniors is costly and usually a waste'],
#   0),
#  (['04/06/2018',
#    'Apples Tim Cook: #MeToo DACA activists and Parkland students are heroes'],
#   0),
#  (['01/06/2018',
#    'Cramers lightning round: Buy B&G Foods on its millennial advantage'],
#   0),
#  (['01/05/2018',
#    'Cramers lightning round: Buy B&G Foods on its millennial advantage'],
#   0),
#  (['04/04/2018', 'Live-Streamed Shootings Continue to Haunt Facebook'], 0),
#  (['04/04/2018',
#    'Tech is under fire but the charts dont point to disaster quite yet: Strategist'],
#   0),
#  (['02/01/2018', 'Automakers post mixed January vehicle sales SUVs in favor'],
#   0),
# ...
#   0),
#  (['01/10/2018', 'After 12 years at the helm two bank CEOs ponder the future'],
#   0),
#  (['01/08/2018',
#    'Cramer: Marijuana bitcoin and Micron are all speculative investments'],
#   0),
#  (['02/05/2018',
#    'UPDATE 1-Brazil defends live cattle export after injunction temporarily lifted'],
#   0),
#  (['02/04/2018',
#    'Warren Buffett on hand as Navy commissions new $440 million warship called the USS Omaha'],
#   0),
#  (['03/02/2018',
#    'Snow storms shut Ireland and force Britain to call in the army'],
#   0),
#  (['03/01/2018',
#    'TREASURIES-U.S. yields dip as Powell dials back optimism on economy'],
#   0),
#  (['03/02/2018',
#    'SEC subpoenas TechCrunch founders cryptofund amid broader investigation into digital coins'],
#   0),
#  (['03/01/2018',
#    'Best Buy to close all 250 of its smaller mobile phone stores'],
#   0),
#  (['02/05/2018', 'U.S. fintech Stripe picks Dublin for new engineering hub'],
#   0),
#  (['03/01/2018',
#    'Exclusive: Israels El Al seeks international help to access Saudi airspace'],
#   0),
#  (['03/01/2018',
#    "Elon Musk responds to Harvard professor Steven Pinkers comments on A.I.'"],
#   0),
#  (['04/05/2018',
#    'UPDATE 3-Brazil judge orders ex-president Lula jailed by Friday'],
#   0),
#  (['02/05/2018',
#    'Singtel to spend up to $413 million to nudge up stake in Indias Bharti Telecom'],
#   0),
#  (['03/02/2018',
#    'Italys election has more similarities with Germany than you might think'],
#   0),
#  (['03/06/2018',
#    'Bill Gates almost didnt meet Warren Buffett and 6 more facts about him you may not know'],
#   0),
#  (['04/05/2018', '4 things to do before opening a credit card'], 0),
#  (['04/05/2018',
#    'Self-made millionaire Robert Herjavec: 4 tips any young person can use to succeed'],
#   0),
#  (['02/04/2018', 'At least 2 dead 50 injured in South Carolina train wreck'],
#   0),
#  (['04/09/2018',
#    'Trudeau attends emotional vigil for Canada bus crash victims'],
#   0),
#  (['04/09/2018',
#    'Why Apple Co-Founder Steve Wozniak Joined the #DeleteFacebook Movement - Fortune'],
#   0),
#  (['04/09/2018', 'Jimmy Kimmel Takes the High Road in Hannity FeudSort Of'],
#   0),
#  (['04/06/2018',
#    'Treasury Secretary Mnuchin: Sanctions are targeting certain behaviors of Russian oligarchs'],
#   0),
#  (['04/03/2018', 'Mozillas Latest Version of Firefox Is Made for VR'], 0),
#  (['04/03/2018',
#    'Sell General Electric shares because a credit rating downgrade is likely ahead: JP Morgan'],
#   0),
#  (['03/01/2018',
#    'Exclusive: Pimco economist Clarida seen as front-runner for Fed deputy job'],
#   0),
#  (['03/06/2018',
#    'Once wary of Facebook and Apple a mill town tells them to keep expanding'],
#   0),
#  (['04/04/2018', 'After-hours buzz: FB OLLI & VIAB'], 0),
#  (['04/05/2018',
#    'Indias central bank bans financial firms from dealing with cryptocurrency'],
#   0),
#  (['04/04/2018', 'Astros finish off three-game sweep of Orioles'], 0),
#  (['04/05/2018', 'Here are all the store closures we know are coming in 2018'],
#   0),
#  (['01/07/2018',
#    'The Mysterious Zuma Mission SpaceXs First Launch of 2018 Is Tonight'],
#   0),
#  (['02/04/2018', 'Major Banks Ban Buying Bitcoin With Your Credit Card'], 0),
#  (['05/03/2018',
#    'Gold prices regain some ground but technician warns they have further to fall'],
#   0),
#  (['03/06/2018',
#    'Poland denies reports of U.S. ban on high-level meetings with Polish officials'],
#   0),
#  (['03/06/2018',
#    'Square is up 200 percent in the last year and has more room to run. Heres why'],
#   0),
#  (['01/12/2018',
#    'JP Morgan lost $143 million last quarter on a loan to a single mystery client'],
#   0),
#  (['01/12/2018',
#    'Facebook is massively changing its News Feed and it may mean people spend less time on it'],
#   0),
#  (['03/05/2018',
#    'Mugabe acolyte forms new Zimbabwe political party to challenge Mnangagwa'],
#   0),
#  (['03/05/2018',
#    'Former Netanyahu spokesman signs states witness deal in corruption probe: Israeli media'],
#   0),
#  (['03/05/2018', "Best move to just keep buying?'"], 0),
#  (['03/06/2018',
#    'US challenges JM Smuckers purchase of Conagras Wesson oil brand'],
#   0),
#  (['03/02/2018', 'A great opportunity to buy Amazon'], 0),
#  (['04/06/2018',
#    'Heres how long it would take the average person to save enough to buy a home in San Francisco'],
#   0),
#  (['04/06/2018', 'The 20 jobs people are least likely to leave'], 0),
#  (['04/04/2018',
#    'Spotifys unique debut that cut out Wall Street is a success so far but bankers shouldnt be too worried'],
#   0),
#  (['01/08/2018',
#    'Toyota unveils self-driving concept vehicle for rides deliveries'],
#   0),
#  (['01/08/2018',
#    'Here are the 10 most important stories for investors Morning morning'],
#   0),
#  (['05/03/2018',
#    'Jobless claims rise modestly; Americans receiving unemployment aid lowest since 1973'],
#   0),
#  (['04/06/2018',
#    'Shares of Japans Monex spike after it agrees to buy troubled cryptocurrency firm'],
#   0),
#  (['04/03/2018',
#    'GRAINS-Wheat rallies after USDA confirms damage from recent dry weather'],
#   0),
#  (['05/01/2018',
#    'The Morning Download: Cloud Giants Experience Even Faster Growth Rates'],
#   0),
#  (['01/08/2018',
#    'Cramer: Its not Apples responsibility to parent your kids iPhone use'],
#   0),
#  (['05/03/2018',
#    "'Next generation flaws found on computer processors: magazine"],
#   0),
#  (['05/03/2018',
#    'Tesla set to drop the day after controversial earnings call'],
#   0),
#  (['01/09/2018',
#    'Cox CEO on AT&T-Time Warner merger: \'I dont think you have to get bigger to compete"'],
#   0),
#  (['01/10/2018',
#    'Britain fines Carphone Warehouse 400000 pounds over data breach'],
#   0),
#  (['01/10/2018', '10 states where you can stretch your 529 on private school'],
#   0),
#  (['01/10/2018', "Millennial moms our 'dream customer: Childrens Place CEO"],
#   0),
#  (['01/10/2018', 'Judges: North Carolina must redraw GOPs gerrymandered map'],
#   0),
#  (['01/10/2018',
#    'More than 100 CEOs pressure Congress to pass immigration bill by shutdown deadline'],
#   0),
#  (['01/10/2018',
#    'Minneapolis Fed proposes massive regulation change for big banks'],
#   0),
#  (['01/10/2018', 'US import prices post smallest gain in five months'], 0),
#  (['04/03/2018',
#    'Artificial Intelligence Could Soon Enhance Real-Time Police Surveillance'],
#   0),
#  (['05/04/2018',
#    'Amid Blockchain Hype Few Deployments Limited Interest Survey Finds'],
#   0),
#  (['05/04/2018',
#    'Warren Buffetts Berkshire Hathaway Just Bought Another 75 Million Apple Shares Report Says'],
#   0),
#  (['05/04/2018',
#    'Bitcoin is rallying  and can no longer be dismissed: Brian Kelly'],
#   0),
#  (['04/04/2018',
#    'How to see everything Twitter knows about you and download your Tweet history'],
#   0),
#  (['04/06/2018', 'These 5 last-minute tax cheats will cost you'], 0),
#  (['04/06/2018', 'The CIA is hunting for its next generation of talent'], 0),
#  (['05/03/2018', 'Varsity Math Week 138'], 0),
#  (['03/06/2018',
#    'US-Mexico relations could get even more complicated if this guy becomes president'],
#   0),
#  (['04/06/2018',
#    'South Africas Zuma proclaims innocence after court appearance'],
#   0),
#  (['04/06/2018',
#    'New study finds that 36% of college students dont have enough to eat'],
#   0),
#  (['04/07/2018', 'Apple Working on Curved iPhone Hiring for Siri'], 0),
#  (['04/05/2018',
#    'Bitcoin exchange Coinbase launches early-stage venture fund'],
#   0),
#  (['04/06/2018', 'The disappearing American car'], 0),
#  (['04/06/2018',
#    'SEC freezes $27 million from stock sales involving CEO of crypto-company Longfin and three others'],
#   0),
#  (['04/06/2018',
#    'More tech workers cant afford to live where they work  and neither can teachers and first responders'],
#   0),
#  (['04/06/2018',
#    'Facebook can remove Mark Zuckerbergs messages from others inboxes  the rest of us cant do that'],
#   0),
#  (['04/06/2018', 'MARCH JOBS: +103K'], 0),
#  (['04/09/2018',
#    'This is the most important level to watch on the S&P 500 right now'],
#   0),
#  (['04/09/2018',
#    'Saudi prince skips visit to mega tech incubator during French trip - Reuters'],
#   0),
#  (['04/09/2018',
#    'FDA orders Bayer to implement additional safety measures on Essure contraception device'],
#   0),
#  (['05/02/2018',
#    'The Morning Download: Facebook Aims for Tighter Integration with the Enterprise'],
#   0),
#  (['05/03/2018',
#    'US worker productivity rises slightly in the fourth quarter as wage growth accelerates'],
#   0),
#  (['05/02/2018', 'Companies Grapple With AIs Opaque Decision-Making Process'],
#   0),
#  (['05/03/2018',
#    'United Airlines recruits former White House press secretary Earnest as communications chief'],
#   0),
#  (['05/03/2018', 'After-hours buzz: CBS SHAK P & more'], 0),
#  (['03/06/2018',
#    'Live from the CERAWeek energy summit: Google Cloud chief Diane Greene'],
#   0),
#  (['04/09/2018',
#    'Rising Crude Prices Hit U.S. Drivers in the PocketbookEnergy Journal'],
#   0),
#  (['03/06/2018',
#    'What its like behind the throttle of a US Army Black Hawk helicopter'],
#   0),
#  (['03/06/2018',
#    'Amazon could become the third-biggest US bank if it wants to: Bain study'],
#   0),
#  (['02/06/2018',
#    'UPDATE 2-Brazil court overturns injunction against live cattle exports'],
#   0),
#  (['03/07/2018',
#    'Immigration officials will keep processing DACA renewals because of court injunctions'],
#   0),
#  (['05/03/2018',
#    'Ethiopia to take a stake in Sudans main sea gateway port - Reuters'],
#   0),
#  (['05/04/2018', 'Cboes Best Quarter Ever Doesnt Impress Investors'], 0),
#  (['05/04/2018', 'The Free Trips Your Financial Adviser Takes Could Cost You'],
#   0),
#  (['05/05/2018',
#    'Warren Buffett Vs. Elon Musk: Whos Better at Selling Candy? - MoneyBeat - WSJ'],
#   0),
#  (['05/05/2018',
#    'Gold can get to 5 year highs if it can clear one technical hurdle: Bank of America'],
#   0),
#  (['05/06/2018', 'The Robots that Milk Cows'], 0),
#  (['03/08/2018', 'What itll take for me to come around on GE'], 0),
#  (['04/06/2018',
#    'Rep. Blake Farenthold resigns from Congress months after harassment accusations surfaced'],
#   0),
#  (['04/07/2018', 'Find the Best National Beer Day Deals and Events Near You'],
#   0),
#  (['04/07/2018',
#    "To dodge the 'sticker shock of New York City residents flock to Jersey City as an alternative"],
#   0),
#  (['02/06/2018',
#    'You Get Sexual Advances 24/7: What Its Really Like to Be a Female Engineer In Silicon Valley'],
#   0),
#  (['05/03/2018', 'The Morning Download: AI Has Some Explaining to Do'], 0),
#  (['05/04/2018',
#    'How to make sure your summer vacation wont wreck your finances'],
#   0),
#  (['05/04/2018', 'The April Jobs Report in 12 Charts'], 0),
#  (['05/02/2018',
#    'A major Chinese manufacturing indicator is expected to show a growth slowdown'],
#   0),
#  (['05/02/2018',
#    'Real Time Economics: Europe stumbles | Share Buybacks |Trade Deadlines - Real Time Economics - WSJ'],
#   0),
#  (['05/02/2018',
#    'U.S. considering restrictions on Chinese telecoms companies: WSJ'],
#   0),
#  (['03/06/2018', 'Live from the Energy Summit: Saudi Aramco CEO Amin Nasser'],
#   0),
#  (['03/06/2018', 'BofA technician makes contrarian bond call'], 0),
#  (['05/04/2018',
#    'Brexit & Beyond: Mixed Picture for British Prime Minister After Local Elections'],
#   0),
#  (['05/03/2018', 'Investors Bet on a Faster Fed - MoneyBeat - WSJ'], 0),
#  (['05/03/2018',
#    'Spurned Tesla Analysts Arent Pleased With Bizarre Earnings Call'],
#   0),
#  (['05/03/2018',
#    'CFOs Confident About U.S. Fundamentals But Fear Protectionism - CFO Journal. - WSJ'],
#   0),
#  (['05/02/2018',
#    'Cramers lightning round: Danaher is one of my favorite charitable trust holdings'],
#   0),
#  (['04/06/2018',
#    'South Koreas Former President Park Geun-hye Is Jailed for 24 Years'],
#   0),
#  (['01/09/2018',
#    'Chinese Uber rival Didi Chuxing launches bike sharing service in highly-competitive market'],
#   0),
#  (['04/09/2018',
#    'WSJ City PM: Deutsches New Dynamic Europes Growing Debt Pile How Big Tech Is Bracing for Privacy Rules'],
#   0),
#  (['04/09/2018', 'BRIEF-Uber Says To Acquire JUMP Bikes - Blog'], 0),
#  (['04/09/2018',
#    'Mark Zuckerberg needs to answer these questions before Congress this week'],
#   0),
#  (['01/09/2018',
#    'Here are the 10 most important stories for investors Tuesday morning'],
#   0),
#  (['02/06/2018', 'Credit Suisse decides to halt XIV ETN'], 0),
#  (['02/06/2018',
#    'See Traders React to the Dows Biggest One-Day Drop in History'],
#   0),
#  (['04/09/2018',
#    'Why Disney Cant Use Spider-Man or the Avengers at Its Orlando LocationEven Though It Owns the Marvel Brand - Fortune'],
#   0),
#  (['04/09/2018', 'Orbans party signals crackdown after victory in Hungary'],
#   0),
#  (['03/06/2018', 'Saudi Aramco CEO on relationship with Russia'], 0),
#  (['03/06/2018',
#    'Special Report: By rewriting history Hindu nationalists aim to assert their dominance over India'],
#   0),
#  (['03/06/2018',
#    'A lost World War II aircraft carrier has been found by one of Microsofts co-founders'],
#   0),
#  (['02/06/2018',
#    'Ukraine power distributor plans cyber defense system for $20 million'],
#   0),
#  (['04/05/2018', "$100B ADDITIONAL TARIFFS ON BEIJING?'"], 0),
#  (['04/07/2018',
#    'Several Killed as Truck Rams Into Small Crowd in Mnster Germany'],
#   0),
#  (['04/09/2018', 'Florida Gov. Rick Scott is running for Senate'], 0),
#  (['04/08/2018',
#    'Netflix Could Pull Films From Cannes in Response to Competition Ban'],
#   0),
#  (['04/09/2018',
#    'WSJ City: Investors Welcome Deutsche Banks CEO Switch US Dials Down Trade Rhetoric'],
#   0),
#  (['04/09/2018',
#    'Northrop Grumman not SpaceX reported to be at fault for loss of top secret Zuma satellite'],
#   0),
#  (['02/05/2018',
#    'IATA warns rising costs for airport infrastructure are risk for airlines'],
#   0),
#  (['02/06/2018',
#    'Suzy Welch: Heres how to talk about being unemployed in a job interview'],
#   0),
#  (['02/06/2018',
#    'New York City Is Warned of an Impending Tsunami as Another False Alert Is Sent'],
#   0),
#  (['02/05/2018',
#    'Cramer: Stop yourself from panicking and find the sell-offs opportunities'],
#   0),
#  (['01/10/2018', 'Mortgage applications shoot up 8.3% to start the year'], 0),
#  (['02/07/2018',
#    'The Toys "R Us Clearance Sales Are About to Begin. Here\\\'s Where to Find Them - Fortune'],
#   0),
#  (['05/03/2018',
#    'Ex-Volkswagen CEO Winterkorn charged in US over diesel scandal'],
#   0),
#  (['05/03/2018',
#    'April job growth expected to be strong and unemployment could hit a new generational low'],
#   0),
#  (['05/04/2018',
#    "The Wall Street Journal: Argentinas third central-bank hike in eight days puts key lending rate at 40%'"],
#   0),
#  (['05/02/2018', 'Apples razor-razorblade model could be huge'], 0),
#  (['04/06/2018',
#    'These are the most used words on LinkedInand how to stand out if you use them'],
#   0),
#  (['04/08/2018',
#    'Turnout high in Hungarys election as Orban fights to retain power'],
#   0),
#  (['04/09/2018',
#    "'None of us will have any privacy anymore: Senator calls for Facebook regulation"],
#   0),
#  (['04/09/2018',
#    'Saudi prince skips visit to mega tech incubator during French trip'],
#   0),
#  (['04/09/2018',
#    'Big money showdown in Florida: Scott vs. Nelson is shaping up to be \'one of the most expensive Senate races ever"'],
#   0),
#  (['04/09/2018', 'Gulf Region Hopes for Windfall from Saudis Emergence'], 0),
#  (['04/09/2018',
#    'The Wall Street Journal: Wells Fargo looks at own auto-lending issues as regulatory pressure builds'],
#   0),
#  (['04/06/2018', 'Japans cryptocurrency exchanges face shortage of engineers'],
#   0),
#  (['01/07/2018',
#    'German opposition calls for abolition of online hate speech law'],
#   0),
#  (['02/05/2018',
#    'Over $60 billion wiped off value of cryptocurrencies as bitcoin drops to lowest level since Nov 18'],
#   0),
#  (['04/05/2018',
#    "'Illegal crossing attempts at US Southwest border triple in March from year ago"],
#   0),
#  (['02/04/2018',
#    'SpaceX Will Try To Recover All Three Falcon Heavy Boosters After Tuesday Test Launch'],
#   0),
#  (['01/09/2018',
#    'Watch: White House press secretary Sarah Sanders briefs reporters'],
#   0),
#  (['01/09/2018', 'Richard Allison to replace Patrick Doyle as Dominos CEO'],
#   0),
#  ...]

# %%
#Headline history suggestions based on predicted cluster with closest result
for i in range(0, labels.shape[0]):
    if labels[i] == predicted:
        print(prev[i])
# Out:
# ['02/02/2018', 'Merck posts mixed fourth-quarter results']
# ['02/01/2018', 'Amazon set to report fourth quarter earnings after the bell']
# ['05/01/2018', 'Pfizers quarterly profit rises 14%"']
# ['03/02/2018', 'Chinas second largest e-commerce site JD.com falls on weak quarterly results']
# ['03/08/2018', 'Fourth quarter went better than previous quarters: Continental CEO']
# ['03/16/2018', 'Tiffany quarterly revenue rises 8.5% on strong holiday quarter']
# ['02/14/2018', 'Groupon tumbles on mixed fourth quarter results']
# ['04/18/2018', 'American Express to report first-quarter earnings after the market close']
# ['01/19/2018', 'Cramers lightning round: Buy Cisco before its quarterly earnings report']
# ['04/18/2018', 'Morgan Stanley shares surge after reporting record revenue for the first-quarter']
# ['04/25/2018', 'Chipotle Mexican Grill to report first-quarter earnings after the bell. Heres what to expect']
# ['05/30/2018', 'Boxs quarterly results top estimates but stock falls after hefty rally']
# ['05/02/2018', 'SouthGobi Resources to announce first quarter 2018 results on May 14 2018']
# ['05/01/2018', 'Carlisle Companies Declares Regular Quarterly Dividend']
# ['05/02/2018', 'Spotify operating loss narrows in first quarterly report']
# ['05/29/2018', 'CORRECTING and REPLACING -- Cavco Industries Reports Fiscal 2018 Fourth Quarter and Year End Results']
# ['05/30/2018', 'Greenfields Petroleum Corporation Announces First Quarter 2018 Results']
# ['04/30/2018', 'McKesson Corporation Fiscal 2018 Fourth Quarter Conference Call Scheduled for May 24 2018']
# ['05/31/2018', 'FRO - First Quarter 2018 Results']
# ['05/30/2018', 'BMO Financial Group Reports Second Quarter 2018 Results']
# ['05/29/2018', 'PagSeguro Reports First Quarter Results']
# ['05/29/2018', 'Salesforce Announces Record First Quarter Fiscal 2019 Results']
# ['05/30/2018', 'Kalytera Reports First Quarter 2018 Financial Results']
# ['05/31/2018', 'China Education Resources Inc. Reports Q1 2018 Financial Results']
# ['05/30/2018', 'InterGen Announces First Quarter 2018 Financial Results']
# ['04/30/2018', 'Cronos Group Inc. Announces Fourth Quarter and Fiscal Year 2017 Results']
# ['04/30/2018', 'Eltek Reports Fourth Quarter and Full Year 2017 Financial Results']
# ['05/31/2018', 'Bradmer Announces First Quarter 2018 Financial Results']
# ['05/30/2018', 'Box Reports Record Revenue of $141 Million and Delivers Cash Flow From Operations of $18 Million for Fiscal First Quarter 2019']
# ['05/30/2018', 'Divestco Reports 2018 Q1 Results']
# ['04/30/2018', 'CORRECTED-BRIEF-Alliance Resource Partners Reports Quarterly Revenue of $457.1 Million']
# ['04/30/2018', 'Martin Marietta Announces First Quarter 2018 Earnings Conference Call']
# ['02/27/2018', 'Camping World Holdings Inc. Reports Fourth Quarter Results']
# ['05/31/2018', 'Streamline Health To Report First Quarter 2018 Financial Performance On June 6 2018']
# ['05/30/2018', 'Flushing Financial Corporation Declares Quarterly Dividend of $0.20 per Share']
# ['05/30/2018', 'Goosehead Insurance Inc. to Report First Quarter 2018 Results on Wednesday June 6 2018']
# ['04/29/2018', 'Horse racing - Jockey Club announces record financial results']
# ['05/31/2018', 'Donaldson Reports Fiscal 2018 Third Quarter Earnings']
# ['04/30/2018', 'Crown Crafts Announces Quarterly Cash Dividend']
# ['05/31/2018', 'Eurocontrol Reports First Quarter 2018 Results']
# ['05/31/2018', 'Tech Data Corporation Reports First Quarter Fiscal Year 2019 Results']
# ['05/29/2018', 'Earth Alive Reports First Quarter 2018 Results']
# ['05/30/2018', 'Walgreens Boots Alliance Schedules Fiscal 2018 Third Quarter Earnings Announcement for 28 June 2018']
# ['05/30/2018', 'Vogogo Releases Financial Results for Final Quarter Prior to Acquisition of Operating Business']
# ['04/30/2018', 'FutureFuel to Release First Quarter Financial Results on May 10 2018']
# ['05/31/2018', 'Kuuhubb Reports Third Financial']
# ['05/31/2018', 'Comerica Announces Conference Call to Review Second Quarter 2018 Earnings']
# ['05/31/2018', 'Dollar General Corporation Reports First Quarter 2018 Financial Results; Reiterates Financial Guidance for Fiscal Year 2018']
# ['05/31/2018', 'Build-A-Bear Workshop Inc. Reports First Quarter Fiscal 2018 Results']
# ['05/31/2018', 'Christopher & Banks Corporation Reports First Quarter Fiscal 2018 Financial Results']
# ['05/30/2018', 'Halmont Properties Corporation First Quarter Results']
